# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor, Pool as CatBoostPool
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold
import warnings
warnings.filterwarnings('ignore')

from multiprocessing import Pool as MultiprocessingPool, cpu_count
from tqdm.auto import tqdm
import pickle

ITERATIONS = 20000

basedir = '/kaggle/input/nfl-big-data-bowl-2026-prediction'

def load_weekly_data(week_num):
    input_df = pd.read_csv(f'{basedir}/train/input_2023_w{week_num:02d}.csv')
    output_df = pd.read_csv(f'{basedir}/train/output_2023_w{week_num:02d}.csv')
    return input_df, output_df

def load_all_train_data():
    print("Loading training data...")
    with MultiprocessingPool(min(cpu_count(), 18)) as pool:
        results = list(tqdm(pool.imap(load_weekly_data, range(1, 19)), total=18))
    
    input_dfs = [r[0] for r in results]
    output_dfs = [r[1] for r in results]
    
    input_data = pd.concat(input_dfs, ignore_index=True)
    output_data = pd.concat(output_dfs, ignore_index=True)
    
    print(f"Input data shape: {input_data.shape}")
    print(f"Output data shape: {output_data.shape}")
    
    return input_data, output_data

def engineer_advanced_features(df):
    """Advanced feature engineering with sequence and interaction features"""
    df = df.copy()
    
    df['velocity_x'] = df['s'] * np.cos(np.radians(df['dir']))
    df['velocity_y'] = df['s'] * np.sin(np.radians(df['dir']))
    
    df['dist_to_ball'] = np.sqrt(
        (df['x'] - df['ball_land_x'])**2 + 
        (df['y'] - df['ball_land_y'])**2
    )
    
    df['angle_to_ball'] = np.arctan2(
        df['ball_land_y'] - df['y'],
        df['ball_land_x'] - df['x']
    )
    
    df['velocity_toward_ball'] = (
        df['velocity_x'] * np.cos(df['angle_to_ball']) + 
        df['velocity_y'] * np.sin(df['angle_to_ball'])
    )
    
    df['time_to_ball'] = df['num_frames_output'] / 10.0
    
    df['orientation_diff'] = np.abs(df['o'] - df['dir'])
    df['orientation_diff'] = np.minimum(df['orientation_diff'], 360 - df['orientation_diff'])
    
    df['role_targeted_receiver'] = (df['player_role'] == 'Targeted Receiver').astype(int)
    df['role_defensive_coverage'] = (df['player_role'] == 'Defensive Coverage').astype(int)
    df['role_passer'] = (df['player_role'] == 'Passer').astype(int)
    df['side_offense'] = (df['player_side'] == 'Offense').astype(int)
    
    height_parts = df['player_height'].str.split('-', expand=True)
    df['height_inches'] = height_parts[0].astype(float) * 12 + height_parts[1].astype(float)
    df['bmi'] = (df['player_weight'] / (df['height_inches']**2)) * 703
    
    df['acceleration_x'] = df['a'] * np.cos(np.radians(df['dir']))
    df['acceleration_y'] = df['a'] * np.sin(np.radians(df['dir']))
    
    df['distance_to_target_x'] = df['ball_land_x'] - df['x']
    df['distance_to_target_y'] = df['ball_land_y'] - df['y']
    
    df['speed_squared'] = df['s'] ** 2
    df['accel_magnitude'] = np.sqrt(df['acceleration_x']**2 + df['acceleration_y']**2)
    
    df['velocity_alignment'] = np.cos(df['angle_to_ball'] - np.radians(df['dir']))
    
    df['expected_x_at_ball'] = df['x'] + df['velocity_x'] * df['time_to_ball']
    df['expected_y_at_ball'] = df['y'] + df['velocity_y'] * df['time_to_ball']
    
    df['error_from_ball_x'] = df['expected_x_at_ball'] - df['ball_land_x']
    df['error_from_ball_y'] = df['expected_y_at_ball'] - df['ball_land_y']
    df['error_from_ball'] = np.sqrt(df['error_from_ball_x']**2 + df['error_from_ball_y']**2)
    
    df['momentum_x'] = df['player_weight'] * df['velocity_x']
    df['momentum_y'] = df['player_weight'] * df['velocity_y']
    
    df['kinetic_energy'] = 0.5 * df['player_weight'] * df['speed_squared']
    
    df['angle_diff'] = np.abs(df['o'] - np.degrees(df['angle_to_ball']))
    df['angle_diff'] = np.minimum(df['angle_diff'], 360 - df['angle_diff'])
    
    df['time_squared'] = df['time_to_ball'] ** 2
    df['dist_squared'] = df['dist_to_ball'] ** 2
    
    df['weighted_dist_by_time'] = df['dist_to_ball'] / (df['time_to_ball'] + 0.1)
    
    return df

def add_sequence_features(df):
    """Add temporal lag and rolling features"""
    df = df.sort_values(['game_id', 'play_id', 'nfl_id', 'frame_id'])
    
    group_cols = ['game_id', 'play_id', 'nfl_id']
    
    for lag in [1, 2, 3, 4, 5]:
        for col in ['x', 'y', 'velocity_x', 'velocity_y', 's', 'a']:
            if col in df.columns:
                df[f'{col}_lag{lag}'] = df.groupby(group_cols)[col].shift(lag)
    
    for window in [3, 5]:
        for col in ['x', 'y', 'velocity_x', 'velocity_y', 's']:
            if col in df.columns:
                df[f'{col}_rolling_mean_{window}'] = df.groupby(group_cols)[col].rolling(window, min_periods=1).mean().reset_index(level=[0,1,2], drop=True)
                df[f'{col}_rolling_std_{window}'] = df.groupby(group_cols)[col].rolling(window, min_periods=1).std().reset_index(level=[0,1,2], drop=True)
    
    for col in ['velocity_x', 'velocity_y']:
        if col in df.columns:
            df[f'{col}_delta'] = df.groupby(group_cols)[col].diff()
    
    return df

def create_training_dataset(input_df, output_df):
    output_df = output_df.copy()
    output_df['id'] = (output_df['game_id'].astype(str) + '_' + 
                       output_df['play_id'].astype(str) + '_' + 
                       output_df['nfl_id'].astype(str) + '_' + 
                       output_df['frame_id'].astype(str))
    
    output_df = output_df.rename(columns={'x': 'target_x', 'y': 'target_y'})
    
    input_agg = input_df.groupby(['game_id', 'play_id', 'nfl_id']).last().reset_index()
    
    if 'frame_id' in input_agg.columns:
        input_agg = input_agg.drop('frame_id', axis=1)
    
    merged = output_df.merge(
        input_agg,
        on=['game_id', 'play_id', 'nfl_id'],
        how='left',
        suffixes=('', '_input')
    )
    
    return merged

def physics_baseline_prediction(x, y, velocity_x, velocity_y, frame_id):
    time_delta = frame_id / 10.0
    pred_x = x + velocity_x * time_delta
    pred_y = y + velocity_y * time_delta
    pred_x = np.clip(pred_x, 0, 120)
    pred_y = np.clip(pred_y, 0, 53.3)
    return pred_x, pred_y

def main():
    print(f"CPU cores: {cpu_count()}")
    
    input_data, output_data = load_all_train_data()
    
    print("\n=== Advanced Feature Engineering ===")
    print("Step 1: Engineering advanced physics features...")
    input_features = engineer_advanced_features(input_data)
    
    print("Step 2: Adding sequence and rolling features...")
    input_features = add_sequence_features(input_features)
    
    print(f"Feature engineered data shape: {input_features.shape}")
    print(f"Total features: {input_features.shape[1]}")
    
    print("\nStep 3: Creating training dataset...")
    train_df = create_training_dataset(input_features, output_data)
    print(f"Training dataset shape: {train_df.shape}")
    
    feature_cols = [
        'x', 'y', 's', 'a', 'o', 'dir',
        'velocity_x', 'velocity_y', 'dist_to_ball', 'angle_to_ball',
        'velocity_toward_ball', 'time_to_ball', 'orientation_diff',
        'role_targeted_receiver', 'role_defensive_coverage', 'role_passer',
        'side_offense', 'height_inches', 'player_weight', 'bmi',
        'ball_land_x', 'ball_land_y', 'num_frames_output', 'frame_id',
        'acceleration_x', 'acceleration_y', 'distance_to_target_x', 'distance_to_target_y',
        'speed_squared', 'accel_magnitude', 'velocity_alignment',
        'expected_x_at_ball', 'expected_y_at_ball',
        'error_from_ball_x', 'error_from_ball_y', 'error_from_ball',
        'momentum_x', 'momentum_y', 'kinetic_energy',
        'angle_diff', 'time_squared', 'dist_squared', 'weighted_dist_by_time'
    ]
    
    for lag in [1, 2, 3, 4, 5]:
        for col in ['x', 'y', 'velocity_x', 'velocity_y', 's', 'a']:
            feature_cols.append(f'{col}_lag{lag}')
    
    for window in [3, 5]:
        for col in ['x', 'y', 'velocity_x', 'velocity_y', 's']:
            feature_cols.append(f'{col}_rolling_mean_{window}')
            feature_cols.append(f'{col}_rolling_std_{window}')
    
    feature_cols.extend(['velocity_x_delta', 'velocity_y_delta'])
    
    available_features = [col for col in feature_cols if col in train_df.columns]
    print(f"Available features: {len(available_features)}")
    
    train_df = train_df.dropna(subset=available_features + ['target_x', 'target_y'])
    print(f"Training data after removing NaNs: {train_df.shape}")
    
    print("\n=== Physics Baseline ===")
    baseline_x, baseline_y = physics_baseline_prediction(
        train_df['x'].values,
        train_df['y'].values,
        train_df['velocity_x'].values,
        train_df['velocity_y'].values,
        train_df['frame_id'].values
    )
    
    baseline_rmse = np.sqrt(
        0.5 * (mean_squared_error(train_df['target_x'], baseline_x) +
               mean_squared_error(train_df['target_y'], baseline_y))
    )
    print(f"Physics Baseline RMSE: {baseline_rmse:.4f}")
    
    # Prepare data for CatBoost
    X = train_df[available_features].values
    y_x = train_df['target_x'].values
    y_y = train_df['target_y'].values
    
    # Initialize 5-fold cross-validation with GroupKFold
    n_folds = 5
    groups = train_df['game_id'].astype(str) + '_' + train_df['play_id'].astype(str)
    kf = GroupKFold(n_splits=n_folds)
    
    models_x = []
    models_y = []
    val_rmse_scores = []
    
    print(f"\n=== Training Ultra-Optimized CatBoost with 5-Fold GroupKFold CV ===")
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(X, groups=groups), 1):
        print(f"\nFold {fold}/{n_folds}")
        
        # Split data
        X_train, X_val = X[train_idx], X[val_idx]
        y_x_train, y_x_val = y_x[train_idx], y_x[val_idx]
        y_y_train, y_y_val = y_y[train_idx], y_y[val_idx]
        
        print(f"Training set: {X_train.shape}, Validation set: {X_val.shape}")
        
        # Define CatBoost Pools
        train_pool_x = CatBoostPool(X_train, y_x_train)
        val_pool_x = CatBoostPool(X_val, y_x_val)
        train_pool_y = CatBoostPool(X_train, y_y_train)
        val_pool_y = CatBoostPool(X_val, y_y_val)
        
        # Train X-coordinate model
        print(f"Training X coordinate model for fold {fold}...")
        model_x = CatBoostRegressor(
            iterations=ITERATIONS,
            learning_rate=0.05,
            depth=10,
            l2_leaf_reg=3.0,
            random_seed=42, 
            task_type='GPU',
            devices='0',
            early_stopping_rounds=500,
            verbose=200,
            loss_function='RMSE'
        )
        
        model_x.fit(
            train_pool_x,
            eval_set=val_pool_x,
            verbose=200
        )
        models_x.append(model_x)
        
        # Train Y-coordinate model
        print(f"Training Y coordinate model for fold {fold}...")
        model_y = CatBoostRegressor(
            iterations=ITERATIONS,
            learning_rate=0.05,
            depth=10,
            l2_leaf_reg=3.0,
            random_seed=42, 
            task_type='GPU',
            devices='0',
            early_stopping_rounds=500,
            verbose=200,
            loss_function='RMSE'
        )
        
        model_y.fit(
            train_pool_y,
            eval_set=val_pool_y,
            verbose=200
        )
        models_y.append(model_y)
        
        # Validation predictions
        pred_x = model_x.predict(X_val)
        pred_y = model_y.predict(X_val)
        
        pred_x = np.clip(pred_x, 0, 120)
        pred_y = np.clip(pred_y, 0, 53.3)
        
        # Compute RMSE for this fold
        fold_rmse = np.sqrt(
            0.5 * (mean_squared_error(y_x_val, pred_x) +
                   mean_squared_error(y_y_val, pred_y))
        )
        val_rmse_scores.append(fold_rmse)
        print(f"Fold {fold} RMSE: {fold_rmse:.4f}")
    
    # Average RMSE across folds
    catboost_rmse = np.mean(val_rmse_scores)
    print(f"\nAverage CatBoost RMSE across {n_folds} folds: {catboost_rmse:.4f}")
    print(f"Standard Deviation of RMSE: {np.std(val_rmse_scores):.4f}")
    
    print(f"\n{'='*60}")
    print(f"ULTRA-OPTIMIZED CATBOOST PERFORMANCE (5-FOLD GROUPKFOLD CV)")
    print(f"{'='*60}")
    print(f"Physics Baseline RMSE:     {baseline_rmse:.4f}")
    print(f"Ultra-Optimized CatBoost:  {catboost_rmse:.4f}")
    print(f"Improvement:               {((baseline_rmse - catboost_rmse) / baseline_rmse * 100):.2f}%")
    print(f"Target RMSE:               0.9000")
    target_met = 'YES - TARGET ACHIEVED!' if catboost_rmse < 0.9 else 'NO - Continuing optimization...'
    print(f"Target Met:                {target_met}")
    print(f"{'='*60}")
    
    # Feature importance (averaged across folds)
    importance_x = np.mean([model.get_feature_importance() for model in models_x], axis=0)
    importance_y = np.mean([model.get_feature_importance() for model in models_y], axis=0)
    
    feature_importance = pd.DataFrame({
        'feature': available_features,
        'importance_x': importance_x,
        'importance_y': importance_y
    })
    feature_importance['importance_avg'] = (feature_importance['importance_x'] + 
                                            feature_importance['importance_y']) / 2
    feature_importance = feature_importance.sort_values('importance_avg', ascending=False)
    
    print("\nTop 30 Most Important Features (Averaged across folds):")
    print(feature_importance.head(30).to_string())
    
    # Save models
    with open('catboost_5fold_models.pkl', 'wb') as f:
        pickle.dump({
            'models_x': models_x,
            'models_y': models_y,
            'features': available_features,
            'rmse': catboost_rmse
        }, f)
    print("\nModels saved to catboost_5fold_models.pkl")
    
    print("\n=== Generating Submission ===")
    test_input = pd.read_csv(f'{basedir}/test_input.csv')
    test_data = pd.read_csv(f'{basedir}/test.csv')
    
    print("Engineering features for test data...")
    test_features = engineer_advanced_features(test_input)
    test_features = add_sequence_features(test_features)
    
    test_agg = test_features.groupby(['game_id', 'play_id', 'nfl_id']).last().reset_index()
    
    if 'frame_id' in test_agg.columns:
        test_agg = test_agg.drop('frame_id', axis=1)
    
    test_merged = test_data.merge(
        test_agg,
        on=['game_id', 'play_id', 'nfl_id'],
        how='left'
    )
    
    test_merged['id'] = (test_merged['game_id'].astype(str) + '_' + 
                         test_merged['play_id'].astype(str) + '_' + 
                         test_merged['nfl_id'].astype(str) + '_' + 
                         test_merged['frame_id'].astype(str))
    
    for col in available_features:
        if col not in test_merged.columns:
            test_merged[col] = 0
    
    X_test = test_merged[available_features].fillna(0).values
    
    # Ensemble predictions across all folds
    pred_x_test = np.mean([model.predict(X_test) for model in models_x], axis=0)
    pred_y_test = np.mean([model.predict(X_test) for model in models_y], axis=0)
    
    pred_x_test = np.clip(pred_x_test, 0, 120)
    pred_y_test = np.clip(pred_y_test, 0, 53.3)
    
    submission = pd.DataFrame({
        'id': test_merged['id'],
        'x': pred_x_test,
        'y': pred_y_test
    })
    
    submission.to_csv('submission.csv', index=False)
    print(f"\n[SUCCESS] Submission saved: submission_catboost_5fold.csv")
    print(f"Shape: {submission.shape}")
    
    print("\n=== Submission Validation ===")
    print(f"No NaN values: {submission.isnull().sum().sum() == 0}")
    print(f"X range: [{submission['x'].min():.2f}, {submission['x'].max():.2f}]")
    print(f"Y range: [{submission['y'].min():.2f}, {submission['y'].max():.2f}]")
    print(f"Unique IDs: {submission['id'].nunique()}")
    
    return catboost_rmse

if __name__ == "__main__":
    final_rmse = main()
    print(f"\n[FINAL] Validation RMSE: {final_rmse:.4f}")
    achievement = 'ACHIEVED!' if final_rmse < 0.9 else 'Not yet - need further optimization'
    print(f"[FINAL] Target RMSE < 0.9: {achievement}")
# Out:
# CPU cores: 4
# Loading training data...
#   0%|          | 0/18 [00:00<?, ?it/s]
# Input data shape: (4880579, 23)
# Output data shape: (562936, 6)
#
# === Advanced Feature Engineering ===
# Step 1: Engineering advanced physics features...
# Step 2: Adding sequence and rolling features...
# Feature engineered data shape: (4880579, 107)
# Total features: 107
#
# Step 3: Creating training dataset...
# Training dataset shape: (562936, 110)
# Available features: 95
# Training data after removing NaNs: (562936, 110)
#
# === Physics Baseline ===
# Physics Baseline RMSE: 5.6845
#
# === Training Ultra-Optimized CatBoost with 5-Fold GroupKFold CV ===
#
# Fold 1/5
# Training set: (450349, 95), Validation set: (112587, 95)
# Training X coordinate model for fold 1...
# 0:	learn: 24.1696307	test: 23.6807726	best: 23.6807726 (0)	total: 482ms	remaining: 2h 40m 46s
# 200:	learn: 0.7569351	test: 0.9556656	best: 0.9556656 (200)	total: 3.94s	remaining: 6m 28s
# 400:	learn: 0.5949448	test: 0.9037158	best: 0.9037158 (400)	total: 7.4s	remaining: 6m 1s
# 600:	learn: 0.5075849	test: 0.8831206	best: 0.8831206 (600)	total: 10.9s	remaining: 5m 52s
# 800:	learn: 0.4450691	test: 0.8747906	best: 0.8747906 (800)	total: 14.5s	remaining: 5m 47s
# 1000:	learn: 0.3993861	test: 0.8700580	best: 0.8700472 (999)	total: 18.1s	remaining: 5m 42s
# 1200:	learn: 0.3640650	test: 0.8680815	best: 0.8679768 (1196)	total: 21.7s	remaining: 5m 38s
# 1400:	learn: 0.3354555	test: 0.8655248	best: 0.8654514 (1399)	total: 25.2s	remaining: 5m 35s
# 1600:	learn: 0.3108880	test: 0.8641221	best: 0.8641220 (1569)	total: 28.9s	remaining: 5m 31s
# 1800:	learn: 0.2899189	test: 0.8631262	best: 0.8629880 (1778)	total: 32.5s	remaining: 5m 28s
# 2000:	learn: 0.2717590	test: 0.8613399	best: 0.8613130 (1997)	total: 36.2s	remaining: 5m 25s
# 2200:	learn: 0.2561680	test: 0.8596907	best: 0.8596907 (2200)	total: 39.8s	remaining: 5m 22s
# 2400:	learn: 0.2416001	test: 0.8588277	best: 0.8586426 (2343)	total: 43.5s	remaining: 5m 19s
# 2600:	learn: 0.2289711	test: 0.8591229	best: 0.8586426 (2343)	total: 47.2s	remaining: 5m 16s
# 2800:	learn: 0.2175598	test: 0.8594163	best: 0.8586426 (2343)	total: 51s	remaining: 5m 13s
# bestTest = 0.8586426139
# bestIteration = 2343
# Shrink model to first 2344 iterations.
# Training Y coordinate model for fold 1...
# 0:	learn: 12.7981107	test: 12.8086598	best: 12.8086598 (0)	total: 18.5ms	remaining: 6m 9s
# 200:	learn: 0.6166660	test: 0.7666618	best: 0.7666618 (200)	total: 3.47s	remaining: 5m 41s
# 400:	learn: 0.4843628	test: 0.7302067	best: 0.7302060 (399)	total: 7.07s	remaining: 5m 45s
# 600:	learn: 0.4113411	test: 0.7182037	best: 0.7182037 (600)	total: 10.7s	remaining: 5m 45s
# 800:	learn: 0.3594193	test: 0.7127467	best: 0.7125824 (791)	total: 14.4s	remaining: 5m 44s
# 1000:	learn: 0.3221029	test: 0.7087913	best: 0.7087805 (999)	total: 18.1s	remaining: 5m 44s
# 1200:	learn: 0.2926925	test: 0.7066419	best: 0.7066419 (1200)	total: 21.9s	remaining: 5m 43s
# 1400:	learn: 0.2687023	test: 0.7046946	best: 0.7044949 (1375)	total: 25.7s	remaining: 5m 41s
# 1600:	learn: 0.2488420	test: 0.7022687	best: 0.7019691 (1591)	total: 29.5s	remaining: 5m 39s
# 1800:	learn: 0.2322728	test: 0.7015662	best: 0.7015662 (1800)	total: 33.4s	remaining: 5m 37s
# 2000:	learn: 0.2181428	test: 0.7012699	best: 0.7011690 (1944)	total: 37.3s	remaining: 5m 35s
# 2200:	learn: 0.2058640	test: 0.7011795	best: 0.7008460 (2124)	total: 41.2s	remaining: 5m 33s
# 2400:	learn: 0.1949192	test: 0.7003776	best: 0.7003776 (2400)	total: 45.1s	remaining: 5m 30s
# 2600:	learn: 0.1853149	test: 0.7006520	best: 0.7003412 (2483)	total: 49.1s	remaining: 5m 28s
# 2800:	learn: 0.1767682	test: 0.6999983	best: 0.6999983 (2800)	total: 53s	remaining: 5m 25s
# 3000:	learn: 0.1688256	test: 0.6998841	best: 0.6998580 (2990)	total: 57s	remaining: 5m 22s
# 3200:	learn: 0.1616584	test: 0.6997210	best: 0.6996530 (3192)	total: 1m	remaining: 5m 20s
# 3400:	learn: 0.1549968	test: 0.6994206	best: 0.6993749 (3386)	total: 1m 4s	remaining: 5m 17s
# 3600:	learn: 0.1487837	test: 0.6990361	best: 0.6990361 (3600)	total: 1m 8s	remaining: 5m 14s
# 3800:	learn: 0.1429446	test: 0.6987148	best: 0.6987148 (3800)	total: 1m 12s	remaining: 5m 10s
# 4000:	learn: 0.1375837	test: 0.6985857	best: 0.6985857 (4000)	total: 1m 16s	remaining: 5m 7s
# 4200:	learn: 0.1326453	test: 0.6984867	best: 0.6984466 (4163)	total: 1m 20s	remaining: 5m 4s
# 4400:	learn: 0.1279341	test: 0.6983817	best: 0.6982636 (4333)	total: 1m 24s	remaining: 5m 1s
# 4600:	learn: 0.1236269	test: 0.6980664	best: 0.6980567 (4592)	total: 1m 28s	remaining: 4m 57s
# 4800:	learn: 0.1197391	test: 0.6979981	best: 0.6979711 (4783)	total: 1m 32s	remaining: 4m 53s
# 5000:	learn: 0.1160243	test: 0.6981018	best: 0.6979599 (4904)	total: 1m 36s	remaining: 4m 49s
# 5200:	learn: 0.1124339	test: 0.6980878	best: 0.6979599 (4904)	total: 1m 40s	remaining: 4m 46s
# 5400:	learn: 0.1090606	test: 0.6979133	best: 0.6978968 (5322)	total: 1m 44s	remaining: 4m 42s
# 5600:	learn: 0.1058457	test: 0.6977427	best: 0.6976990 (5563)	total: 1m 48s	remaining: 4m 38s
# 5800:	learn: 0.1028758	test: 0.6976448	best: 0.6976441 (5765)	total: 1m 52s	remaining: 4m 35s
# 6000:	learn: 0.1000956	test: 0.6976625	best: 0.6976155 (5810)	total: 1m 56s	remaining: 4m 31s
# 6200:	learn: 0.0974852	test: 0.6975175	best: 0.6974977 (6194)	total: 2m	remaining: 4m 27s
# 6400:	learn: 0.0949463	test: 0.6975795	best: 0.6974731 (6296)	total: 2m 4s	remaining: 4m 23s
# 6600:	learn: 0.0924315	test: 0.6973619	best: 0.6973370 (6576)	total: 2m 8s	remaining: 4m 20s
# 6800:	learn: 0.0901219	test: 0.6973101	best: 0.6972786 (6779)	total: 2m 12s	remaining: 4m 16s
# 7000:	learn: 0.0878030	test: 0.6972594	best: 0.6972007 (6950)	total: 2m 16s	remaining: 4m 12s
# 7200:	learn: 0.0856664	test: 0.6972438	best: 0.6972007 (6950)	total: 2m 20s	remaining: 4m 9s
# 7400:	learn: 0.0837143	test: 0.6973265	best: 0.6972007 (6950)	total: 2m 24s	remaining: 4m 5s
# bestTest = 0.6972007231
# bestIteration = 6950
# Shrink model to first 6951 iterations.
# Fold 1 RMSE: 0.7821
#
# Fold 2/5
# Training set: (450345, 95), Validation set: (112591, 95)
# Training X coordinate model for fold 2...
# 0:	learn: 24.0977002	test: 23.9765253	best: 23.9765253 (0)	total: 31ms	remaining: 10m 19s
# 200:	learn: 0.7610811	test: 0.9158005	best: 0.9158005 (200)	total: 3.43s	remaining: 5m 37s
# 400:	learn: 0.5999225	test: 0.8560201	best: 0.8560201 (400)	total: 6.88s	remaining: 5m 36s
# 600:	learn: 0.5107912	test: 0.8404517	best: 0.8404014 (597)	total: 10.4s	remaining: 5m 36s
# 800:	learn: 0.4491952	test: 0.8320058	best: 0.8320058 (800)	total: 14s	remaining: 5m 36s
# 1000:	learn: 0.4051314	test: 0.8274971	best: 0.8274971 (1000)	total: 17.6s	remaining: 5m 34s
# 1200:	learn: 0.3679658	test: 0.8239172	best: 0.8237722 (1195)	total: 21.4s	remaining: 5m 34s
# 1400:	learn: 0.3379627	test: 0.8202141	best: 0.8202141 (1400)	total: 25.1s	remaining: 5m 33s
# 1600:	learn: 0.3128047	test: 0.8180486	best: 0.8180338 (1598)	total: 28.8s	remaining: 5m 31s
# 1800:	learn: 0.2916756	test: 0.8158681	best: 0.8158324 (1798)	total: 32.6s	remaining: 5m 29s
# 2000:	learn: 0.2735140	test: 0.8141555	best: 0.8141555 (2000)	total: 36.3s	remaining: 5m 26s
# 2200:	learn: 0.2577930	test: 0.8129393	best: 0.8129001 (2190)	total: 40.1s	remaining: 5m 24s
# 2400:	learn: 0.2431162	test: 0.8121562	best: 0.8121562 (2400)	total: 43.8s	remaining: 5m 21s
# 2600:	learn: 0.2301394	test: 0.8111493	best: 0.8111174 (2596)	total: 47.7s	remaining: 5m 18s
# 2800:	learn: 0.2185538	test: 0.8108871	best: 0.8107866 (2756)	total: 51.4s	remaining: 5m 15s
# 3000:	learn: 0.2079909	test: 0.8104186	best: 0.8104186 (3000)	total: 55.2s	remaining: 5m 12s
# 3200:	learn: 0.1988288	test: 0.8099714	best: 0.8099593 (3199)	total: 58.9s	remaining: 5m 9s
# 3400:	learn: 0.1902718	test: 0.8094477	best: 0.8094477 (3400)	total: 1m 2s	remaining: 5m 5s
# 3600:	learn: 0.1822677	test: 0.8089719	best: 0.8089584 (3598)	total: 1m 6s	remaining: 5m 2s
# 3800:	learn: 0.1749328	test: 0.8082331	best: 0.8082221 (3795)	total: 1m 10s	remaining: 4m 59s
# 4000:	learn: 0.1682029	test: 0.8079510	best: 0.8079383 (3988)	total: 1m 13s	remaining: 4m 55s
# 4200:	learn: 0.1618625	test: 0.8075830	best: 0.8075778 (4192)	total: 1m 17s	remaining: 4m 52s
# 4400:	learn: 0.1560460	test: 0.8072149	best: 0.8072134 (4399)	total: 1m 21s	remaining: 4m 48s
# 4600:	learn: 0.1506736	test: 0.8071903	best: 0.8071706 (4562)	total: 1m 25s	remaining: 4m 45s
# 4800:	learn: 0.1454710	test: 0.8069680	best: 0.8069565 (4799)	total: 1m 29s	remaining: 4m 41s
# 5000:	learn: 0.1405180	test: 0.8067522	best: 0.8067522 (5000)	total: 1m 32s	remaining: 4m 38s
# 5200:	learn: 0.1359414	test: 0.8064609	best: 0.8064548 (5194)	total: 1m 36s	remaining: 4m 34s
# 5400:	learn: 0.1316840	test: 0.8061972	best: 0.8061972 (5400)	total: 1m 40s	remaining: 4m 31s
# 5600:	learn: 0.1277742	test: 0.8059794	best: 0.8059788 (5599)	total: 1m 44s	remaining: 4m 27s
# 5800:	learn: 0.1239517	test: 0.8057504	best: 0.8057462 (5787)	total: 1m 48s	remaining: 4m 24s
# 6000:	learn: 0.1203293	test: 0.8055061	best: 0.8054976 (5997)	total: 1m 51s	remaining: 4m 20s
# 6200:	learn: 0.1169493	test: 0.8054321	best: 0.8054250 (6194)	total: 1m 55s	remaining: 4m 17s
# 6400:	learn: 0.1137153	test: 0.8052559	best: 0.8052441 (6397)	total: 1m 59s	remaining: 4m 13s
# 6600:	learn: 0.1105648	test: 0.8051150	best: 0.8051150 (6600)	total: 2m 3s	remaining: 4m 10s
# 6800:	learn: 0.1077548	test: 0.8049619	best: 0.8049468 (6789)	total: 2m 7s	remaining: 4m 6s
# 7000:	learn: 0.1048763	test: 0.8048935	best: 0.8048915 (6927)	total: 2m 10s	remaining: 4m 3s
# 7200:	learn: 0.1023511	test: 0.8048051	best: 0.8048038 (7198)	total: 2m 14s	remaining: 3m 59s
# 7400:	learn: 0.0997568	test: 0.8046855	best: 0.8046849 (7394)	total: 2m 18s	remaining: 3m 56s
# 7600:	learn: 0.0973254	test: 0.8046015	best: 0.8045885 (7577)	total: 2m 22s	remaining: 3m 52s
# 7800:	learn: 0.0950194	test: 0.8045757	best: 0.8045384 (7748)	total: 2m 26s	remaining: 3m 48s
# 8000:	learn: 0.0927593	test: 0.8045162	best: 0.8045124 (7999)	total: 2m 30s	remaining: 3m 45s
# 8200:	learn: 0.0907211	test: 0.8043725	best: 0.8043693 (8192)	total: 2m 34s	remaining: 3m 41s
# 8400:	learn: 0.0887668	test: 0.8042742	best: 0.8042742 (8400)	total: 2m 37s	remaining: 3m 37s
# 8600:	learn: 0.0867893	test: 0.8042046	best: 0.8042046 (8600)	total: 2m 41s	remaining: 3m 34s
# 8800:	learn: 0.0850897	test: 0.8041451	best: 0.8041431 (8799)	total: 2m 45s	remaining: 3m 30s
# 9000:	learn: 0.0833903	test: 0.8041573	best: 0.8041341 (8809)	total: 2m 49s	remaining: 3m 26s
# 9200:	learn: 0.0817162	test: 0.8041379	best: 0.8041341 (8809)	total: 2m 53s	remaining: 3m 23s
# 9400:	learn: 0.0800739	test: 0.8040244	best: 0.8040154 (9392)	total: 2m 56s	remaining: 3m 19s
# 9600:	learn: 0.0785293	test: 0.8039873	best: 0.8039723 (9461)	total: 3m	remaining: 3m 15s
# 9800:	learn: 0.0769825	test: 0.8039355	best: 0.8039348 (9692)	total: 3m 4s	remaining: 3m 12s
# 10000:	learn: 0.0755497	test: 0.8038635	best: 0.8038623 (9999)	total: 3m 8s	remaining: 3m 8s
# 10200:	learn: 0.0741928	test: 0.8038034	best: 0.8037875 (10177)	total: 3m 12s	remaining: 3m 4s
# 10400:	learn: 0.0728601	test: 0.8037843	best: 0.8037776 (10307)	total: 3m 15s	remaining: 3m
# 10600:	learn: 0.0715477	test: 0.8037282	best: 0.8037140 (10529)	total: 3m 19s	remaining: 2m 57s
# 10800:	learn: 0.0703625	test: 0.8036419	best: 0.8036398 (10797)	total: 3m 23s	remaining: 2m 53s
# 11000:	learn: 0.0691652	test: 0.8036238	best: 0.8036156 (10962)	total: 3m 27s	remaining: 2m 49s
# 11200:	learn: 0.0680423	test: 0.8036349	best: 0.8036155 (11013)	total: 3m 31s	remaining: 2m 45s
# 11400:	learn: 0.0669619	test: 0.8035954	best: 0.8035873 (11372)	total: 3m 35s	remaining: 2m 42s
# 11600:	learn: 0.0658776	test: 0.8035557	best: 0.8035549 (11598)	total: 3m 38s	remaining: 2m 38s
# 11800:	learn: 0.0648341	test: 0.8035189	best: 0.8035163 (11795)	total: 3m 42s	remaining: 2m 34s
# 12000:	learn: 0.0638384	test: 0.8035132	best: 0.8035132 (12000)	total: 3m 46s	remaining: 2m 31s
# 12200:	learn: 0.0628400	test: 0.8034539	best: 0.8034515 (12167)	total: 3m 50s	remaining: 2m 27s
# 12400:	learn: 0.0619064	test: 0.8034432	best: 0.8034432 (12400)	total: 3m 54s	remaining: 2m 23s
# 12600:	learn: 0.0610170	test: 0.8034267	best: 0.8034087 (12553)	total: 3m 58s	remaining: 2m 19s
# 12800:	learn: 0.0601224	test: 0.8034154	best: 0.8034075 (12772)	total: 4m 1s	remaining: 2m 16s
# 13000:	learn: 0.0592691	test: 0.8033644	best: 0.8033644 (13000)	total: 4m 5s	remaining: 2m 12s
# 13200:	learn: 0.0584526	test: 0.8033680	best: 0.8033496 (13054)	total: 4m 9s	remaining: 2m 8s
# 13400:	learn: 0.0576541	test: 0.8033549	best: 0.8033476 (13393)	total: 4m 13s	remaining: 2m 4s
# 13600:	learn: 0.0568989	test: 0.8033281	best: 0.8033106 (13540)	total: 4m 17s	remaining: 2m
# 13800:	learn: 0.0561360	test: 0.8032972	best: 0.8032969 (13799)	total: 4m 20s	remaining: 1m 57s
# 14000:	learn: 0.0553981	test: 0.8032898	best: 0.8032766 (13895)	total: 4m 24s	remaining: 1m 53s
# 14200:	learn: 0.0546933	test: 0.8032651	best: 0.8032635 (14198)	total: 4m 28s	remaining: 1m 49s
# 14400:	learn: 0.0540019	test: 0.8032438	best: 0.8032424 (14393)	total: 4m 32s	remaining: 1m 45s
# 14600:	learn: 0.0533120	test: 0.8032468	best: 0.8032307 (14548)	total: 4m 36s	remaining: 1m 42s
# 14800:	learn: 0.0526790	test: 0.8032494	best: 0.8032307 (14548)	total: 4m 39s	remaining: 1m 38s
# 15000:	learn: 0.0520357	test: 0.8032321	best: 0.8032307 (14548)	total: 4m 43s	remaining: 1m 34s
# 15200:	learn: 0.0514554	test: 0.8032067	best: 0.8032060 (15186)	total: 4m 47s	remaining: 1m 30s
# 15400:	learn: 0.0508467	test: 0.8031597	best: 0.8031544 (15388)	total: 4m 51s	remaining: 1m 27s
# 15600:	learn: 0.0502431	test: 0.8031250	best: 0.8031250 (15600)	total: 4m 55s	remaining: 1m 23s
# 15800:	learn: 0.0496534	test: 0.8031131	best: 0.8031043 (15733)	total: 4m 58s	remaining: 1m 19s
# 16000:	learn: 0.0490885	test: 0.8031075	best: 0.8030937 (15938)	total: 5m 2s	remaining: 1m 15s
# 16200:	learn: 0.0485607	test: 0.8030917	best: 0.8030881 (16158)	total: 5m 6s	remaining: 1m 11s
# 16400:	learn: 0.0480057	test: 0.8030705	best: 0.8030704 (16399)	total: 5m 10s	remaining: 1m 8s
# 16600:	learn: 0.0474926	test: 0.8030717	best: 0.8030644 (16504)	total: 5m 14s	remaining: 1m 4s
# 16800:	learn: 0.0469690	test: 0.8030574	best: 0.8030574 (16800)	total: 5m 18s	remaining: 1m
# 17000:	learn: 0.0464984	test: 0.8030338	best: 0.8030332 (16998)	total: 5m 21s	remaining: 56.8s
# 17200:	learn: 0.0459919	test: 0.8030371	best: 0.8030194 (17096)	total: 5m 25s	remaining: 53s
# 17400:	learn: 0.0455431	test: 0.8030129	best: 0.8030102 (17394)	total: 5m 29s	remaining: 49.2s
# 17600:	learn: 0.0450566	test: 0.8030058	best: 0.8030043 (17577)	total: 5m 33s	remaining: 45.4s
# 17800:	learn: 0.0446073	test: 0.8029825	best: 0.8029812 (17797)	total: 5m 37s	remaining: 41.6s
# 18000:	learn: 0.0441981	test: 0.8029626	best: 0.8029626 (18000)	total: 5m 40s	remaining: 37.9s
# 18200:	learn: 0.0437764	test: 0.8029524	best: 0.8029485 (18190)	total: 5m 44s	remaining: 34.1s
# 18400:	learn: 0.0433692	test: 0.8029421	best: 0.8029369 (18262)	total: 5m 48s	remaining: 30.3s
# 18600:	learn: 0.0429439	test: 0.8029303	best: 0.8029277 (18595)	total: 5m 52s	remaining: 26.5s
# 18800:	learn: 0.0425434	test: 0.8028927	best: 0.8028921 (18791)	total: 5m 56s	remaining: 22.7s
# 19000:	learn: 0.0421473	test: 0.8028812	best: 0.8028774 (18900)	total: 5m 59s	remaining: 18.9s
# 19200:	learn: 0.0417479	test: 0.8028762	best: 0.8028674 (19180)	total: 6m 3s	remaining: 15.1s
# 19400:	learn: 0.0413663	test: 0.8028545	best: 0.8028511 (19395)	total: 6m 7s	remaining: 11.3s
# 19600:	learn: 0.0409889	test: 0.8028397	best: 0.8028359 (19586)	total: 6m 11s	remaining: 7.56s
# 19800:	learn: 0.0406239	test: 0.8028258	best: 0.8028251 (19747)	total: 6m 15s	remaining: 3.77s
# 19999:	learn: 0.0402693	test: 0.8028168	best: 0.8028130 (19992)	total: 6m 18s	remaining: 0us
# bestTest = 0.8028130128
# bestIteration = 19992
# Shrink model to first 19993 iterations.
# Training Y coordinate model for fold 2...
# 0:	learn: 12.7957875	test: 12.8232117	best: 12.8232117 (0)	total: 34.1ms	remaining: 11m 22s
# 200:	learn: 0.6223911	test: 0.7842587	best: 0.7842587 (200)	total: 3.54s	remaining: 5m 48s
# 400:	learn: 0.4835837	test: 0.7384595	best: 0.7384595 (400)	total: 7.15s	remaining: 5m 49s
# 600:	learn: 0.4098439	test: 0.7232722	best: 0.7232667 (598)	total: 10.8s	remaining: 5m 47s
# 800:	learn: 0.3603270	test: 0.7136016	best: 0.7135092 (798)	total: 14.4s	remaining: 5m 45s
# 1000:	learn: 0.3230355	test: 0.7092918	best: 0.7091651 (990)	total: 18.1s	remaining: 5m 43s
# 1200:	learn: 0.2941875	test: 0.7054224	best: 0.7054166 (1198)	total: 21.8s	remaining: 5m 41s
# 1400:	learn: 0.2713169	test: 0.7023851	best: 0.7023851 (1400)	total: 25.6s	remaining: 5m 39s
# 1600:	learn: 0.2520478	test: 0.7007993	best: 0.7007993 (1600)	total: 29.3s	remaining: 5m 36s
# 1800:	learn: 0.2361988	test: 0.6991850	best: 0.6991688 (1797)	total: 33s	remaining: 5m 33s
# 2000:	learn: 0.2221177	test: 0.6978874	best: 0.6978791 (1993)	total: 36.8s	remaining: 5m 31s
# 2200:	learn: 0.2095408	test: 0.6970031	best: 0.6970031 (2200)	total: 40.6s	remaining: 5m 28s
# 2400:	learn: 0.1984128	test: 0.6958018	best: 0.6958018 (2400)	total: 44.4s	remaining: 5m 25s
# 2600:	learn: 0.1879959	test: 0.6953328	best: 0.6952766 (2580)	total: 48.2s	remaining: 5m 22s
# 2800:	learn: 0.1789078	test: 0.6946310	best: 0.6946310 (2800)	total: 52s	remaining: 5m 19s
# 3000:	learn: 0.1711005	test: 0.6940573	best: 0.6940469 (2994)	total: 55.7s	remaining: 5m 15s
# 3200:	learn: 0.1636468	test: 0.6935356	best: 0.6934601 (3174)	total: 59.5s	remaining: 5m 12s
# 3400:	learn: 0.1567784	test: 0.6932592	best: 0.6932489 (3398)	total: 1m 3s	remaining: 5m 8s
# 3600:	learn: 0.1505765	test: 0.6928490	best: 0.6928414 (3596)	total: 1m 7s	remaining: 5m 5s
# 3800:	learn: 0.1447912	test: 0.6925485	best: 0.6925292 (3760)	total: 1m 10s	remaining: 5m 1s
# 4000:	learn: 0.1394103	test: 0.6922541	best: 0.6922418 (3988)	total: 1m 14s	remaining: 4m 58s
# 4200:	learn: 0.1342566	test: 0.6920402	best: 0.6920402 (4200)	total: 1m 18s	remaining: 4m 55s
# 4400:	learn: 0.1296842	test: 0.6916515	best: 0.6916485 (4399)	total: 1m 22s	remaining: 4m 51s
# 4600:	learn: 0.1253386	test: 0.6914746	best: 0.6914746 (4600)	total: 1m 26s	remaining: 4m 48s
# 4800:	learn: 0.1213626	test: 0.6914100	best: 0.6913717 (4705)	total: 1m 29s	remaining: 4m 44s
# 5000:	learn: 0.1174825	test: 0.6912227	best: 0.6912227 (5000)	total: 1m 33s	remaining: 4m 40s
# 5200:	learn: 0.1139030	test: 0.6910815	best: 0.6910702 (5186)	total: 1m 37s	remaining: 4m 37s
# 5400:	learn: 0.1104788	test: 0.6909945	best: 0.6909544 (5362)	total: 1m 41s	remaining: 4m 33s
# 5600:	learn: 0.1073107	test: 0.6907806	best: 0.6907806 (5600)	total: 1m 45s	remaining: 4m 30s
# 5800:	learn: 0.1043367	test: 0.6906576	best: 0.6906527 (5798)	total: 1m 48s	remaining: 4m 26s
# 6000:	learn: 0.1014271	test: 0.6904915	best: 0.6904842 (5991)	total: 1m 52s	remaining: 4m 23s
# 6200:	learn: 0.0986429	test: 0.6903613	best: 0.6903613 (6200)	total: 1m 56s	remaining: 4m 19s
# 6400:	learn: 0.0960437	test: 0.6902717	best: 0.6902717 (6400)	total: 2m	remaining: 4m 15s
# 6600:	learn: 0.0935918	test: 0.6902080	best: 0.6902043 (6596)	total: 2m 4s	remaining: 4m 12s
# 6800:	learn: 0.0912902	test: 0.6900870	best: 0.6900870 (6800)	total: 2m 8s	remaining: 4m 8s
# 7000:	learn: 0.0890698	test: 0.6899381	best: 0.6899191 (6948)	total: 2m 11s	remaining: 4m 4s
# 7200:	learn: 0.0867991	test: 0.6898985	best: 0.6898952 (7195)	total: 2m 15s	remaining: 4m 1s
# 7400:	learn: 0.0847503	test: 0.6898470	best: 0.6898373 (7347)	total: 2m 19s	remaining: 3m 57s
# 7600:	learn: 0.0827944	test: 0.6898277	best: 0.6898209 (7597)	total: 2m 23s	remaining: 3m 53s
# 7800:	learn: 0.0809502	test: 0.6898053	best: 0.6897608 (7734)	total: 2m 27s	remaining: 3m 50s
# 8000:	learn: 0.0791854	test: 0.6897351	best: 0.6897327 (7997)	total: 2m 31s	remaining: 3m 46s
# 8200:	learn: 0.0775033	test: 0.6897299	best: 0.6896956 (8069)	total: 2m 34s	remaining: 3m 42s
# 8400:	learn: 0.0758810	test: 0.6896954	best: 0.6896871 (8364)	total: 2m 38s	remaining: 3m 39s
# 8600:	learn: 0.0743523	test: 0.6896189	best: 0.6896189 (8600)	total: 2m 42s	remaining: 3m 35s
# 8800:	learn: 0.0728492	test: 0.6895528	best: 0.6895348 (8792)	total: 2m 46s	remaining: 3m 31s
# 9000:	learn: 0.0714328	test: 0.6894642	best: 0.6894593 (8979)	total: 2m 50s	remaining: 3m 28s
# 9200:	learn: 0.0700726	test: 0.6894148	best: 0.6894056 (9198)	total: 2m 54s	remaining: 3m 24s
# 9400:	learn: 0.0687278	test: 0.6893582	best: 0.6893461 (9356)	total: 2m 57s	remaining: 3m 20s
# 9600:	learn: 0.0674383	test: 0.6893071	best: 0.6893038 (9534)	total: 3m 1s	remaining: 3m 16s
# 9800:	learn: 0.0662415	test: 0.6892367	best: 0.6892280 (9796)	total: 3m 5s	remaining: 3m 13s
# 10000:	learn: 0.0650783	test: 0.6891985	best: 0.6891942 (9949)	total: 3m 9s	remaining: 3m 9s
# 10200:	learn: 0.0639107	test: 0.6891629	best: 0.6891527 (10164)	total: 3m 13s	remaining: 3m 5s
# 10400:	learn: 0.0628242	test: 0.6891464	best: 0.6891396 (10370)	total: 3m 17s	remaining: 3m 1s
# 10600:	learn: 0.0617785	test: 0.6891538	best: 0.6891278 (10448)	total: 3m 20s	remaining: 2m 58s
# 10800:	learn: 0.0607852	test: 0.6891390	best: 0.6891278 (10448)	total: 3m 24s	remaining: 2m 54s
# 11000:	learn: 0.0597828	test: 0.6890716	best: 0.6890716 (11000)	total: 3m 28s	remaining: 2m 50s
# 11200:	learn: 0.0588455	test: 0.6890471	best: 0.6890441 (11197)	total: 3m 32s	remaining: 2m 46s
# 11400:	learn: 0.0579067	test: 0.6889941	best: 0.6889888 (11373)	total: 3m 36s	remaining: 2m 43s
# 11600:	learn: 0.0570323	test: 0.6889223	best: 0.6889196 (11597)	total: 3m 40s	remaining: 2m 39s
# 11800:	learn: 0.0561631	test: 0.6889233	best: 0.6889121 (11704)	total: 3m 43s	remaining: 2m 35s
# 12000:	learn: 0.0553215	test: 0.6889035	best: 0.6889023 (11991)	total: 3m 47s	remaining: 2m 31s
# 12200:	learn: 0.0545448	test: 0.6888563	best: 0.6888563 (12200)	total: 3m 51s	remaining: 2m 27s
# 12400:	learn: 0.0537621	test: 0.6888260	best: 0.6888199 (12396)	total: 3m 55s	remaining: 2m 24s
# 12600:	learn: 0.0530136	test: 0.6888163	best: 0.6888064 (12518)	total: 3m 59s	remaining: 2m 20s
# 12800:	learn: 0.0522602	test: 0.6888163	best: 0.6888064 (12518)	total: 4m 2s	remaining: 2m 16s
# 13000:	learn: 0.0515150	test: 0.6888116	best: 0.6888064 (12518)	total: 4m 6s	remaining: 2m 12s
# 13200:	learn: 0.0508116	test: 0.6887990	best: 0.6887939 (13149)	total: 4m 10s	remaining: 2m 9s
# 13400:	learn: 0.0501707	test: 0.6887846	best: 0.6887794 (13348)	total: 4m 14s	remaining: 2m 5s
# 13600:	learn: 0.0495272	test: 0.6887465	best: 0.6887401 (13582)	total: 4m 18s	remaining: 2m 1s
# 13800:	learn: 0.0489152	test: 0.6887574	best: 0.6887401 (13582)	total: 4m 22s	remaining: 1m 57s
# 14000:	learn: 0.0483071	test: 0.6887145	best: 0.6887118 (13982)	total: 4m 25s	remaining: 1m 53s
# 14200:	learn: 0.0477275	test: 0.6887206	best: 0.6887112 (14043)	total: 4m 29s	remaining: 1m 50s
# 14400:	learn: 0.0471414	test: 0.6887083	best: 0.6887049 (14375)	total: 4m 33s	remaining: 1m 46s
# 14600:	learn: 0.0465936	test: 0.6886920	best: 0.6886920 (14600)	total: 4m 37s	remaining: 1m 42s
# 14800:	learn: 0.0460465	test: 0.6886552	best: 0.6886545 (14799)	total: 4m 41s	remaining: 1m 38s
# 15000:	learn: 0.0455182	test: 0.6886472	best: 0.6886471 (14999)	total: 4m 45s	remaining: 1m 35s
# 15200:	learn: 0.0450150	test: 0.6886277	best: 0.6886272 (15196)	total: 4m 48s	remaining: 1m 31s
# 15400:	learn: 0.0444914	test: 0.6886122	best: 0.6886103 (15384)	total: 4m 52s	remaining: 1m 27s
# 15600:	learn: 0.0440023	test: 0.6886070	best: 0.6886055 (15599)	total: 4m 56s	remaining: 1m 23s
# 15800:	learn: 0.0435381	test: 0.6885881	best: 0.6885881 (15800)	total: 5m	remaining: 1m 19s
# 16000:	learn: 0.0430850	test: 0.6885798	best: 0.6885740 (15916)	total: 5m 4s	remaining: 1m 16s
# 16200:	learn: 0.0426331	test: 0.6885795	best: 0.6885740 (15916)	total: 5m 7s	remaining: 1m 12s
# 16400:	learn: 0.0421726	test: 0.6885601	best: 0.6885597 (16391)	total: 5m 11s	remaining: 1m 8s
# 16600:	learn: 0.0417403	test: 0.6885515	best: 0.6885468 (16465)	total: 5m 15s	remaining: 1m 4s
# 16800:	learn: 0.0413093	test: 0.6885309	best: 0.6885261 (16769)	total: 5m 19s	remaining: 1m
# 17000:	learn: 0.0408903	test: 0.6885168	best: 0.6885144 (16968)	total: 5m 23s	remaining: 57s
# 17200:	learn: 0.0404878	test: 0.6885183	best: 0.6885144 (16968)	total: 5m 27s	remaining: 53.2s
# 17400:	learn: 0.0400987	test: 0.6885022	best: 0.6885020 (17383)	total: 5m 30s	remaining: 49.4s
# 17600:	learn: 0.0397072	test: 0.6884909	best: 0.6884909 (17600)	total: 5m 34s	remaining: 45.6s
# 17800:	learn: 0.0393305	test: 0.6884767	best: 0.6884767 (17800)	total: 5m 38s	remaining: 41.8s
# 18000:	learn: 0.0389462	test: 0.6884602	best: 0.6884590 (17992)	total: 5m 42s	remaining: 38s
# 18200:	learn: 0.0386026	test: 0.6884604	best: 0.6884565 (18184)	total: 5m 46s	remaining: 34.2s
# 18400:	learn: 0.0382417	test: 0.6884406	best: 0.6884377 (18381)	total: 5m 49s	remaining: 30.4s
# 18600:	learn: 0.0378914	test: 0.6884332	best: 0.6884308 (18506)	total: 5m 53s	remaining: 26.6s
# 18800:	learn: 0.0375669	test: 0.6884233	best: 0.6884185 (18771)	total: 5m 57s	remaining: 22.8s
# 19000:	learn: 0.0372277	test: 0.6884341	best: 0.6884160 (18822)	total: 6m 1s	remaining: 19s
# 19200:	learn: 0.0369009	test: 0.6884471	best: 0.6884160 (18822)	total: 6m 5s	remaining: 15.2s
# bestTest = 0.6884159968
# bestIteration = 18822
# Shrink model to first 18823 iterations.
# Fold 2 RMSE: 0.7478
#
# Fold 3/5
# Training set: (450350, 95), Validation set: (112586, 95)
# Training X coordinate model for fold 3...
# 0:	learn: 24.0287190	test: 24.2578595	best: 24.2578595 (0)	total: 31.1ms	remaining: 10m 21s
# 200:	learn: 0.7582803	test: 0.8510143	best: 0.8510143 (200)	total: 3.4s	remaining: 5m 34s
# 400:	learn: 0.5980369	test: 0.7912684	best: 0.7912684 (400)	total: 6.82s	remaining: 5m 33s
# 600:	learn: 0.5100411	test: 0.7717641	best: 0.7717641 (600)	total: 10.3s	remaining: 5m 33s
# 800:	learn: 0.4498105	test: 0.7596460	best: 0.7596460 (800)	total: 13.9s	remaining: 5m 32s
# 1000:	learn: 0.4038670	test: 0.7515704	best: 0.7515704 (1000)	total: 17.4s	remaining: 5m 31s
# 1200:	learn: 0.3680644	test: 0.7463167	best: 0.7463167 (1200)	total: 21.1s	remaining: 5m 29s
# 1400:	learn: 0.3381957	test: 0.7432788	best: 0.7432590 (1396)	total: 24.8s	remaining: 5m 28s
# 1600:	learn: 0.3134834	test: 0.7401432	best: 0.7401432 (1600)	total: 28.4s	remaining: 5m 26s
# 1800:	learn: 0.2914779	test: 0.7388055	best: 0.7388055 (1800)	total: 32.2s	remaining: 5m 25s
# 2000:	learn: 0.2732421	test: 0.7371974	best: 0.7371950 (1999)	total: 36s	remaining: 5m 23s
# 2200:	learn: 0.2570590	test: 0.7358072	best: 0.7357769 (2197)	total: 39.8s	remaining: 5m 21s
# 2400:	learn: 0.2430685	test: 0.7342312	best: 0.7342312 (2400)	total: 43.6s	remaining: 5m 19s
# 2600:	learn: 0.2306324	test: 0.7331426	best: 0.7331426 (2600)	total: 47.3s	remaining: 5m 16s
# 2800:	learn: 0.2192070	test: 0.7324648	best: 0.7324648 (2800)	total: 51.1s	remaining: 5m 13s
# 3000:	learn: 0.2089302	test: 0.7318226	best: 0.7318137 (2996)	total: 54.9s	remaining: 5m 10s
# 3200:	learn: 0.1992584	test: 0.7312779	best: 0.7312656 (3176)	total: 58.6s	remaining: 5m 7s
# 3400:	learn: 0.1907654	test: 0.7305755	best: 0.7305669 (3397)	total: 1m 2s	remaining: 5m 4s
# 3600:	learn: 0.1826734	test: 0.7300864	best: 0.7300808 (3598)	total: 1m 6s	remaining: 5m 1s
# 3800:	learn: 0.1753649	test: 0.7294977	best: 0.7294977 (3800)	total: 1m 9s	remaining: 4m 57s
# 4000:	learn: 0.1685493	test: 0.7289658	best: 0.7289442 (3997)	total: 1m 13s	remaining: 4m 54s
# 4200:	learn: 0.1622969	test: 0.7285216	best: 0.7285216 (4200)	total: 1m 17s	remaining: 4m 50s
# 4400:	learn: 0.1561174	test: 0.7281293	best: 0.7281251 (4399)	total: 1m 21s	remaining: 4m 47s
# 4600:	learn: 0.1504960	test: 0.7279860	best: 0.7279528 (4587)	total: 1m 24s	remaining: 4m 44s
# 4800:	learn: 0.1453386	test: 0.7277204	best: 0.7277132 (4796)	total: 1m 28s	remaining: 4m 40s
# 5000:	learn: 0.1404732	test: 0.7274622	best: 0.7274403 (4986)	total: 1m 32s	remaining: 4m 37s
# 5200:	learn: 0.1360980	test: 0.7272014	best: 0.7271853 (5185)	total: 1m 36s	remaining: 4m 33s
# 5400:	learn: 0.1318719	test: 0.7271636	best: 0.7271322 (5262)	total: 1m 39s	remaining: 4m 30s
# 5600:	learn: 0.1277958	test: 0.7269993	best: 0.7269857 (5593)	total: 1m 43s	remaining: 4m 26s
# 5800:	learn: 0.1240523	test: 0.7268925	best: 0.7268736 (5711)	total: 1m 47s	remaining: 4m 23s
# 6000:	learn: 0.1204143	test: 0.7266622	best: 0.7266603 (5999)	total: 1m 51s	remaining: 4m 19s
# 6200:	learn: 0.1169058	test: 0.7265267	best: 0.7265109 (6181)	total: 1m 55s	remaining: 4m 16s
# 6400:	learn: 0.1136987	test: 0.7264534	best: 0.7264534 (6400)	total: 1m 59s	remaining: 4m 12s
# 6600:	learn: 0.1107482	test: 0.7263979	best: 0.7263725 (6487)	total: 2m 2s	remaining: 4m 9s
# 6800:	learn: 0.1079267	test: 0.7262562	best: 0.7262551 (6798)	total: 2m 6s	remaining: 4m 5s
# 7000:	learn: 0.1050764	test: 0.7261714	best: 0.7261680 (6998)	total: 2m 10s	remaining: 4m 2s
# 7200:	learn: 0.1024264	test: 0.7260816	best: 0.7260784 (7195)	total: 2m 14s	remaining: 3m 58s
# 7400:	learn: 0.1000518	test: 0.7259664	best: 0.7259559 (7373)	total: 2m 18s	remaining: 3m 55s
# 7600:	learn: 0.0976285	test: 0.7258859	best: 0.7258849 (7598)	total: 2m 21s	remaining: 3m 51s
# 7800:	learn: 0.0954229	test: 0.7258254	best: 0.7258254 (7800)	total: 2m 25s	remaining: 3m 47s
# 8000:	learn: 0.0931736	test: 0.7257555	best: 0.7257456 (7990)	total: 2m 29s	remaining: 3m 44s
# 8200:	learn: 0.0910655	test: 0.7256894	best: 0.7256894 (8200)	total: 2m 33s	remaining: 3m 40s
# 8400:	learn: 0.0891197	test: 0.7256228	best: 0.7256035 (8299)	total: 2m 37s	remaining: 3m 37s
# 8600:	learn: 0.0872223	test: 0.7255865	best: 0.7255803 (8532)	total: 2m 41s	remaining: 3m 33s
# 8800:	learn: 0.0854025	test: 0.7255368	best: 0.7255353 (8796)	total: 2m 44s	remaining: 3m 29s
# 9000:	learn: 0.0836477	test: 0.7254989	best: 0.7254830 (8937)	total: 2m 48s	remaining: 3m 26s
# 9200:	learn: 0.0819542	test: 0.7254841	best: 0.7254645 (9149)	total: 2m 52s	remaining: 3m 22s
# 9400:	learn: 0.0803862	test: 0.7254878	best: 0.7254645 (9149)	total: 2m 56s	remaining: 3m 18s
# 9600:	learn: 0.0788424	test: 0.7254437	best: 0.7254419 (9502)	total: 3m	remaining: 3m 15s
# 9800:	learn: 0.0773717	test: 0.7254441	best: 0.7254258 (9736)	total: 3m 3s	remaining: 3m 11s
# 10000:	learn: 0.0759844	test: 0.7253647	best: 0.7253646 (9999)	total: 3m 7s	remaining: 3m 7s
# 10200:	learn: 0.0745507	test: 0.7253211	best: 0.7253157 (10180)	total: 3m 11s	remaining: 3m 3s
# 10400:	learn: 0.0732394	test: 0.7252983	best: 0.7252943 (10363)	total: 3m 15s	remaining: 3m
# 10600:	learn: 0.0718969	test: 0.7252757	best: 0.7252757 (10600)	total: 3m 19s	remaining: 2m 56s
# 10800:	learn: 0.0706048	test: 0.7252424	best: 0.7252276 (10713)	total: 3m 22s	remaining: 2m 52s
# 11000:	learn: 0.0693865	test: 0.7252183	best: 0.7252139 (10945)	total: 3m 26s	remaining: 2m 49s
# 11200:	learn: 0.0682721	test: 0.7251948	best: 0.7251896 (11147)	total: 3m 30s	remaining: 2m 45s
# 11400:	learn: 0.0672008	test: 0.7251791	best: 0.7251782 (11381)	total: 3m 34s	remaining: 2m 41s
# 11600:	learn: 0.0661211	test: 0.7251760	best: 0.7251622 (11560)	total: 3m 38s	remaining: 2m 38s
# 11800:	learn: 0.0650787	test: 0.7251478	best: 0.7251471 (11796)	total: 3m 42s	remaining: 2m 34s
# 12000:	learn: 0.0640587	test: 0.7251407	best: 0.7251356 (11864)	total: 3m 45s	remaining: 2m 30s
# 12200:	learn: 0.0630492	test: 0.7250931	best: 0.7250926 (12199)	total: 3m 49s	remaining: 2m 26s
# 12400:	learn: 0.0621836	test: 0.7250548	best: 0.7250494 (12396)	total: 3m 53s	remaining: 2m 23s
# 12600:	learn: 0.0612718	test: 0.7250312	best: 0.7250300 (12592)	total: 3m 57s	remaining: 2m 19s
# 12800:	learn: 0.0603629	test: 0.7249740	best: 0.7249724 (12786)	total: 4m 1s	remaining: 2m 15s
# 13000:	learn: 0.0595336	test: 0.7249549	best: 0.7249549 (13000)	total: 4m 4s	remaining: 2m 11s
# 13200:	learn: 0.0586851	test: 0.7249225	best: 0.7249207 (13188)	total: 4m 8s	remaining: 2m 8s
# 13400:	learn: 0.0578800	test: 0.7248953	best: 0.7248953 (13400)	total: 4m 12s	remaining: 2m 4s
# 13600:	learn: 0.0570969	test: 0.7248800	best: 0.7248757 (13474)	total: 4m 16s	remaining: 2m
# 13800:	learn: 0.0563291	test: 0.7248740	best: 0.7248728 (13786)	total: 4m 20s	remaining: 1m 56s
# 14000:	learn: 0.0556036	test: 0.7248582	best: 0.7248544 (13901)	total: 4m 24s	remaining: 1m 53s
# 14200:	learn: 0.0548861	test: 0.7248218	best: 0.7248216 (14199)	total: 4m 27s	remaining: 1m 49s
# 14400:	learn: 0.0541963	test: 0.7248124	best: 0.7248072 (14260)	total: 4m 31s	remaining: 1m 45s
# 14600:	learn: 0.0535206	test: 0.7248013	best: 0.7248013 (14600)	total: 4m 35s	remaining: 1m 41s
# 14800:	learn: 0.0528539	test: 0.7247816	best: 0.7247799 (14796)	total: 4m 39s	remaining: 1m 38s
# 15000:	learn: 0.0522260	test: 0.7247684	best: 0.7247627 (14971)	total: 4m 43s	remaining: 1m 34s
# 15200:	learn: 0.0516521	test: 0.7247486	best: 0.7247482 (15198)	total: 4m 46s	remaining: 1m 30s
# 15400:	learn: 0.0510631	test: 0.7247363	best: 0.7247316 (15283)	total: 4m 50s	remaining: 1m 26s
# 15600:	learn: 0.0504873	test: 0.7247332	best: 0.7247270 (15577)	total: 4m 54s	remaining: 1m 23s
# 15800:	learn: 0.0498874	test: 0.7247357	best: 0.7247235 (15652)	total: 4m 58s	remaining: 1m 19s
# 16000:	learn: 0.0493396	test: 0.7247417	best: 0.7247235 (15652)	total: 5m 2s	remaining: 1m 15s
# bestTest = 0.7247235264
# bestIteration = 15652
# Shrink model to first 15653 iterations.
# Training Y coordinate model for fold 3...
# 0:	learn: 12.7707963	test: 12.9199609	best: 12.9199609 (0)	total: 17.7ms	remaining: 5m 54s
# 200:	learn: 0.6231652	test: 0.7140828	best: 0.7140828 (200)	total: 3.49s	remaining: 5m 43s
# 400:	learn: 0.4928812	test: 0.6707037	best: 0.6707037 (400)	total: 7.04s	remaining: 5m 44s
# 600:	learn: 0.4163245	test: 0.6545090	best: 0.6545090 (600)	total: 10.7s	remaining: 5m 44s
# 800:	learn: 0.3646603	test: 0.6467818	best: 0.6467818 (800)	total: 14.3s	remaining: 5m 42s
# 1000:	learn: 0.3265694	test: 0.6417983	best: 0.6417940 (997)	total: 18s	remaining: 5m 41s
# 1200:	learn: 0.2969801	test: 0.6381525	best: 0.6381525 (1200)	total: 21.7s	remaining: 5m 39s
# 1400:	learn: 0.2726216	test: 0.6354949	best: 0.6354383 (1397)	total: 25.4s	remaining: 5m 37s
# 1600:	learn: 0.2528835	test: 0.6335782	best: 0.6335426 (1597)	total: 29.1s	remaining: 5m 34s
# 1800:	learn: 0.2361186	test: 0.6325891	best: 0.6325891 (1800)	total: 32.9s	remaining: 5m 32s
# 2000:	learn: 0.2216081	test: 0.6316550	best: 0.6316391 (1992)	total: 36.6s	remaining: 5m 29s
# 2200:	learn: 0.2092150	test: 0.6308990	best: 0.6308669 (2186)	total: 40.4s	remaining: 5m 26s
# 2400:	learn: 0.1977566	test: 0.6302381	best: 0.6302304 (2399)	total: 44.2s	remaining: 5m 23s
# 2600:	learn: 0.1879076	test: 0.6296686	best: 0.6296318 (2584)	total: 47.9s	remaining: 5m 20s
# 2800:	learn: 0.1788495	test: 0.6289960	best: 0.6289749 (2798)	total: 51.7s	remaining: 5m 17s
# 3000:	learn: 0.1705903	test: 0.6286587	best: 0.6286567 (2998)	total: 55.5s	remaining: 5m 14s
# 3200:	learn: 0.1630819	test: 0.6282366	best: 0.6282149 (3189)	total: 59.4s	remaining: 5m 11s
# 3400:	learn: 0.1563731	test: 0.6280702	best: 0.6280646 (3397)	total: 1m 3s	remaining: 5m 8s
# 3600:	learn: 0.1502237	test: 0.6277400	best: 0.6277400 (3600)	total: 1m 6s	remaining: 5m 4s
# 3800:	learn: 0.1445752	test: 0.6275852	best: 0.6275850 (3799)	total: 1m 10s	remaining: 5m 1s
# 4000:	learn: 0.1391029	test: 0.6272571	best: 0.6272571 (4000)	total: 1m 14s	remaining: 4m 58s
# 4200:	learn: 0.1340880	test: 0.6270140	best: 0.6269995 (4190)	total: 1m 18s	remaining: 4m 54s
# 4400:	learn: 0.1293920	test: 0.6268713	best: 0.6268511 (4395)	total: 1m 22s	remaining: 4m 51s
# 4600:	learn: 0.1249931	test: 0.6267450	best: 0.6267389 (4562)	total: 1m 26s	remaining: 4m 48s
# 4800:	learn: 0.1210071	test: 0.6267227	best: 0.6266746 (4700)	total: 1m 29s	remaining: 4m 44s
# 5000:	learn: 0.1172661	test: 0.6265970	best: 0.6265965 (4999)	total: 1m 33s	remaining: 4m 40s
# 5200:	learn: 0.1136457	test: 0.6265684	best: 0.6265344 (5186)	total: 1m 37s	remaining: 4m 37s
# 5400:	learn: 0.1103430	test: 0.6265149	best: 0.6264970 (5343)	total: 1m 41s	remaining: 4m 33s
# 5600:	learn: 0.1072331	test: 0.6263493	best: 0.6263434 (5598)	total: 1m 45s	remaining: 4m 30s
# 5800:	learn: 0.1041675	test: 0.6263174	best: 0.6263081 (5798)	total: 1m 48s	remaining: 4m 26s
# 6000:	learn: 0.1012126	test: 0.6262073	best: 0.6262067 (5993)	total: 1m 52s	remaining: 4m 23s
# 6200:	learn: 0.0985937	test: 0.6261328	best: 0.6261181 (6189)	total: 1m 56s	remaining: 4m 19s
# 6400:	learn: 0.0959990	test: 0.6260603	best: 0.6260513 (6394)	total: 2m	remaining: 4m 15s
# 6600:	learn: 0.0935126	test: 0.6260377	best: 0.6260337 (6588)	total: 2m 4s	remaining: 4m 12s
# 6800:	learn: 0.0911587	test: 0.6259869	best: 0.6259841 (6705)	total: 2m 8s	remaining: 4m 8s
# 7000:	learn: 0.0889373	test: 0.6258826	best: 0.6258826 (7000)	total: 2m 11s	remaining: 4m 4s
# 7200:	learn: 0.0867285	test: 0.6257485	best: 0.6257438 (7198)	total: 2m 15s	remaining: 4m 1s
# 7400:	learn: 0.0846703	test: 0.6257112	best: 0.6257057 (7375)	total: 2m 19s	remaining: 3m 57s
# 7600:	learn: 0.0828169	test: 0.6256484	best: 0.6256388 (7534)	total: 2m 23s	remaining: 3m 53s
# 7800:	learn: 0.0809827	test: 0.6255960	best: 0.6255938 (7790)	total: 2m 27s	remaining: 3m 50s
# 8000:	learn: 0.0792460	test: 0.6255509	best: 0.6255509 (8000)	total: 2m 31s	remaining: 3m 46s
# 8200:	learn: 0.0775811	test: 0.6254842	best: 0.6254842 (8200)	total: 2m 34s	remaining: 3m 42s
# 8400:	learn: 0.0760395	test: 0.6253998	best: 0.6253981 (8398)	total: 2m 38s	remaining: 3m 39s
# 8600:	learn: 0.0744795	test: 0.6254044	best: 0.6253815 (8422)	total: 2m 42s	remaining: 3m 35s
# 8800:	learn: 0.0730142	test: 0.6253961	best: 0.6253815 (8422)	total: 2m 46s	remaining: 3m 31s
# 9000:	learn: 0.0715847	test: 0.6253513	best: 0.6253398 (8982)	total: 2m 50s	remaining: 3m 27s
# 9200:	learn: 0.0702134	test: 0.6252990	best: 0.6252968 (9193)	total: 2m 53s	remaining: 3m 24s
# 9400:	learn: 0.0688991	test: 0.6252407	best: 0.6252407 (9400)	total: 2m 57s	remaining: 3m 20s
# 9600:	learn: 0.0676060	test: 0.6252174	best: 0.6252026 (9554)	total: 3m 1s	remaining: 3m 16s
# 9800:	learn: 0.0664136	test: 0.6251990	best: 0.6251920 (9764)	total: 3m 5s	remaining: 3m 12s
# 10000:	learn: 0.0652471	test: 0.6251227	best: 0.6251227 (10000)	total: 3m 9s	remaining: 3m 9s
# 10200:	learn: 0.0641319	test: 0.6251325	best: 0.6250996 (10107)	total: 3m 13s	remaining: 3m 5s
# 10400:	learn: 0.0629788	test: 0.6251056	best: 0.6250996 (10107)	total: 3m 16s	remaining: 3m 1s
# 10600:	learn: 0.0619240	test: 0.6250841	best: 0.6250805 (10582)	total: 3m 20s	remaining: 2m 58s
# 10800:	learn: 0.0609229	test: 0.6250653	best: 0.6250631 (10771)	total: 3m 24s	remaining: 2m 54s
# 11000:	learn: 0.0599257	test: 0.6250321	best: 0.6250315 (10982)	total: 3m 28s	remaining: 2m 50s
# 11200:	learn: 0.0589963	test: 0.6250239	best: 0.6250129 (11166)	total: 3m 32s	remaining: 2m 46s
# 11400:	learn: 0.0580737	test: 0.6250070	best: 0.6250001 (11387)	total: 3m 36s	remaining: 2m 42s
# 11600:	learn: 0.0571951	test: 0.6249750	best: 0.6249662 (11564)	total: 3m 39s	remaining: 2m 39s
# 11800:	learn: 0.0563409	test: 0.6249457	best: 0.6249437 (11720)	total: 3m 43s	remaining: 2m 35s
# 12000:	learn: 0.0554942	test: 0.6249344	best: 0.6249255 (11964)	total: 3m 47s	remaining: 2m 31s
# 12200:	learn: 0.0547190	test: 0.6249156	best: 0.6249137 (12195)	total: 3m 51s	remaining: 2m 27s
# 12400:	learn: 0.0539702	test: 0.6249126	best: 0.6249096 (12238)	total: 3m 55s	remaining: 2m 24s
# 12600:	learn: 0.0532128	test: 0.6248843	best: 0.6248811 (12596)	total: 3m 58s	remaining: 2m 20s
# 12800:	learn: 0.0524959	test: 0.6248772	best: 0.6248726 (12793)	total: 4m 2s	remaining: 2m 16s
# 13000:	learn: 0.0518218	test: 0.6248802	best: 0.6248726 (12793)	total: 4m 6s	remaining: 2m 12s
# 13200:	learn: 0.0511410	test: 0.6248750	best: 0.6248676 (13077)	total: 4m 10s	remaining: 2m 8s
# 13400:	learn: 0.0505114	test: 0.6248777	best: 0.6248676 (13077)	total: 4m 14s	remaining: 2m 5s
# bestTest = 0.6248676427
# bestIteration = 13077
# Shrink model to first 13078 iterations.
# Fold 3 RMSE: 0.6766
#
# Fold 4/5
# Training set: (450350, 95), Validation set: (112586, 95)
# Training X coordinate model for fold 4...
# 0:	learn: 23.9488704	test: 24.5520130	best: 24.5520130 (0)	total: 31.5ms	remaining: 10m 29s
# 200:	learn: 0.7626727	test: 0.8622436	best: 0.8622436 (200)	total: 3.39s	remaining: 5m 34s
# 400:	learn: 0.6011757	test: 0.8093323	best: 0.8093323 (400)	total: 6.78s	remaining: 5m 31s
# 600:	learn: 0.5105328	test: 0.7875936	best: 0.7875900 (597)	total: 10.3s	remaining: 5m 31s
# 800:	learn: 0.4502848	test: 0.7765197	best: 0.7763940 (798)	total: 13.8s	remaining: 5m 30s
# 1000:	learn: 0.4045825	test: 0.7688821	best: 0.7688821 (1000)	total: 17.3s	remaining: 5m 29s
# 1200:	learn: 0.3685209	test: 0.7635757	best: 0.7635757 (1200)	total: 21s	remaining: 5m 28s
# 1400:	learn: 0.3390666	test: 0.7600121	best: 0.7599953 (1398)	total: 24.6s	remaining: 5m 26s
# 1600:	learn: 0.3141476	test: 0.7567809	best: 0.7567800 (1599)	total: 28.3s	remaining: 5m 24s
# 1800:	learn: 0.2933013	test: 0.7540068	best: 0.7540068 (1800)	total: 31.9s	remaining: 5m 22s
# 2000:	learn: 0.2752495	test: 0.7525452	best: 0.7525004 (1985)	total: 35.7s	remaining: 5m 20s
# 2200:	learn: 0.2588412	test: 0.7510111	best: 0.7510111 (2200)	total: 39.4s	remaining: 5m 18s
# 2400:	learn: 0.2443598	test: 0.7499999	best: 0.7499833 (2391)	total: 43.2s	remaining: 5m 16s
# 2600:	learn: 0.2315975	test: 0.7489374	best: 0.7489374 (2600)	total: 46.9s	remaining: 5m 13s
# 2800:	learn: 0.2200610	test: 0.7481073	best: 0.7480669 (2793)	total: 50.6s	remaining: 5m 10s
# 3000:	learn: 0.2095458	test: 0.7470299	best: 0.7470232 (2996)	total: 54.4s	remaining: 5m 7s
# 3200:	learn: 0.1999296	test: 0.7465225	best: 0.7465116 (3196)	total: 58.1s	remaining: 5m 4s
# 3400:	learn: 0.1912300	test: 0.7460755	best: 0.7460388 (3398)	total: 1m 1s	remaining: 5m 1s
# 3600:	learn: 0.1831334	test: 0.7455289	best: 0.7455279 (3599)	total: 1m 5s	remaining: 4m 58s
# 3800:	learn: 0.1755199	test: 0.7450566	best: 0.7450410 (3792)	total: 1m 9s	remaining: 4m 55s
# 4000:	learn: 0.1684991	test: 0.7447295	best: 0.7447244 (3999)	total: 1m 13s	remaining: 4m 51s
# 4200:	learn: 0.1621234	test: 0.7442833	best: 0.7442833 (4200)	total: 1m 16s	remaining: 4m 48s
# 4400:	learn: 0.1561456	test: 0.7439133	best: 0.7439133 (4400)	total: 1m 20s	remaining: 4m 45s
# 4600:	learn: 0.1506383	test: 0.7435697	best: 0.7435610 (4598)	total: 1m 24s	remaining: 4m 41s
# 4800:	learn: 0.1454236	test: 0.7432818	best: 0.7432790 (4799)	total: 1m 27s	remaining: 4m 38s
# 5000:	learn: 0.1406800	test: 0.7431383	best: 0.7431378 (4971)	total: 1m 31s	remaining: 4m 35s
# 5200:	learn: 0.1362295	test: 0.7429330	best: 0.7429330 (5200)	total: 1m 35s	remaining: 4m 31s
# 5400:	learn: 0.1318991	test: 0.7426447	best: 0.7426407 (5396)	total: 1m 39s	remaining: 4m 28s
# 5600:	learn: 0.1277396	test: 0.7423769	best: 0.7423712 (5584)	total: 1m 42s	remaining: 4m 24s
# 5800:	learn: 0.1239714	test: 0.7422822	best: 0.7422706 (5782)	total: 1m 46s	remaining: 4m 21s
# 6000:	learn: 0.1202483	test: 0.7421366	best: 0.7421366 (6000)	total: 1m 50s	remaining: 4m 17s
# 6200:	learn: 0.1168150	test: 0.7420186	best: 0.7419900 (6183)	total: 1m 54s	remaining: 4m 14s
# 6400:	learn: 0.1136872	test: 0.7419225	best: 0.7418942 (6367)	total: 1m 58s	remaining: 4m 10s
# 6600:	learn: 0.1106739	test: 0.7418015	best: 0.7418015 (6600)	total: 2m 1s	remaining: 4m 7s
# 6800:	learn: 0.1076725	test: 0.7416933	best: 0.7416780 (6772)	total: 2m 5s	remaining: 4m 3s
# 7000:	learn: 0.1048587	test: 0.7416325	best: 0.7415983 (6979)	total: 2m 9s	remaining: 4m
# 7200:	learn: 0.1021612	test: 0.7415477	best: 0.7415469 (7199)	total: 2m 13s	remaining: 3m 56s
# 7400:	learn: 0.0997128	test: 0.7415091	best: 0.7414801 (7283)	total: 2m 17s	remaining: 3m 53s
# 7600:	learn: 0.0973263	test: 0.7413596	best: 0.7413591 (7599)	total: 2m 20s	remaining: 3m 49s
# 7800:	learn: 0.0951037	test: 0.7413155	best: 0.7413081 (7754)	total: 2m 24s	remaining: 3m 46s
# 8000:	learn: 0.0929128	test: 0.7412283	best: 0.7412183 (7981)	total: 2m 28s	remaining: 3m 42s
# 8200:	learn: 0.0908545	test: 0.7411679	best: 0.7411661 (8191)	total: 2m 32s	remaining: 3m 39s
# 8400:	learn: 0.0888804	test: 0.7410929	best: 0.7410925 (8399)	total: 2m 36s	remaining: 3m 35s
# 8600:	learn: 0.0869891	test: 0.7410584	best: 0.7410509 (8597)	total: 2m 39s	remaining: 3m 31s
# 8800:	learn: 0.0852137	test: 0.7410038	best: 0.7409974 (8766)	total: 2m 43s	remaining: 3m 28s
# 9000:	learn: 0.0835014	test: 0.7409935	best: 0.7409678 (8878)	total: 2m 47s	remaining: 3m 24s
# 9200:	learn: 0.0816921	test: 0.7409524	best: 0.7409427 (9178)	total: 2m 51s	remaining: 3m 20s
# 9400:	learn: 0.0800874	test: 0.7409551	best: 0.7409427 (9178)	total: 2m 55s	remaining: 3m 17s
# 9600:	learn: 0.0785403	test: 0.7409381	best: 0.7409253 (9566)	total: 2m 58s	remaining: 3m 13s
# 9800:	learn: 0.0770986	test: 0.7408923	best: 0.7408906 (9798)	total: 3m 2s	remaining: 3m 10s
# 10000:	learn: 0.0756636	test: 0.7408256	best: 0.7408256 (10000)	total: 3m 6s	remaining: 3m 6s
# 10200:	learn: 0.0743238	test: 0.7407807	best: 0.7407807 (10200)	total: 3m 10s	remaining: 3m 2s
# 10400:	learn: 0.0730136	test: 0.7407568	best: 0.7407558 (10399)	total: 3m 13s	remaining: 2m 58s
# 10600:	learn: 0.0716926	test: 0.7407161	best: 0.7407161 (10600)	total: 3m 17s	remaining: 2m 55s
# 10800:	learn: 0.0704253	test: 0.7406976	best: 0.7406962 (10747)	total: 3m 21s	remaining: 2m 51s
# 11000:	learn: 0.0691802	test: 0.7406299	best: 0.7406279 (10993)	total: 3m 25s	remaining: 2m 47s
# 11200:	learn: 0.0680079	test: 0.7406164	best: 0.7406164 (11199)	total: 3m 29s	remaining: 2m 44s
# 11400:	learn: 0.0668853	test: 0.7405984	best: 0.7405954 (11398)	total: 3m 32s	remaining: 2m 40s
# 11600:	learn: 0.0658261	test: 0.7406133	best: 0.7405921 (11460)	total: 3m 36s	remaining: 2m 36s
# 11800:	learn: 0.0647899	test: 0.7405576	best: 0.7405523 (11795)	total: 3m 40s	remaining: 2m 33s
# 12000:	learn: 0.0638054	test: 0.7405403	best: 0.7405390 (11998)	total: 3m 44s	remaining: 2m 29s
# 12200:	learn: 0.0628066	test: 0.7405170	best: 0.7405098 (12189)	total: 3m 48s	remaining: 2m 25s
# 12400:	learn: 0.0619074	test: 0.7404890	best: 0.7404890 (12400)	total: 3m 51s	remaining: 2m 22s
# 12600:	learn: 0.0610423	test: 0.7404549	best: 0.7404523 (12597)	total: 3m 55s	remaining: 2m 18s
# 12800:	learn: 0.0601242	test: 0.7404142	best: 0.7404142 (12797)	total: 3m 59s	remaining: 2m 14s
# 13000:	learn: 0.0592942	test: 0.7403893	best: 0.7403893 (13000)	total: 4m 3s	remaining: 2m 10s
# 13200:	learn: 0.0584431	test: 0.7403863	best: 0.7403803 (13063)	total: 4m 6s	remaining: 2m 7s
# 13400:	learn: 0.0576179	test: 0.7403491	best: 0.7403453 (13385)	total: 4m 10s	remaining: 2m 3s
# 13600:	learn: 0.0568471	test: 0.7403439	best: 0.7403416 (13548)	total: 4m 14s	remaining: 1m 59s
# 13800:	learn: 0.0560762	test: 0.7403337	best: 0.7403169 (13770)	total: 4m 18s	remaining: 1m 56s
# 14000:	learn: 0.0553854	test: 0.7403206	best: 0.7403117 (13897)	total: 4m 22s	remaining: 1m 52s
# 14200:	learn: 0.0546608	test: 0.7403078	best: 0.7403065 (14190)	total: 4m 25s	remaining: 1m 48s
# 14400:	learn: 0.0539993	test: 0.7402916	best: 0.7402907 (14399)	total: 4m 29s	remaining: 1m 44s
# 14600:	learn: 0.0532687	test: 0.7402842	best: 0.7402815 (14555)	total: 4m 33s	remaining: 1m 41s
# 14800:	learn: 0.0525764	test: 0.7402833	best: 0.7402671 (14707)	total: 4m 37s	remaining: 1m 37s
# 15000:	learn: 0.0519469	test: 0.7402734	best: 0.7402671 (14707)	total: 4m 41s	remaining: 1m 33s
# 15200:	learn: 0.0513362	test: 0.7402345	best: 0.7402339 (15198)	total: 4m 44s	remaining: 1m 29s
# 15400:	learn: 0.0507352	test: 0.7402138	best: 0.7402126 (15398)	total: 4m 48s	remaining: 1m 26s
# 15600:	learn: 0.0501724	test: 0.7401940	best: 0.7401940 (15600)	total: 4m 52s	remaining: 1m 22s
# 15800:	learn: 0.0495774	test: 0.7402075	best: 0.7401896 (15695)	total: 4m 56s	remaining: 1m 18s
# 16000:	learn: 0.0490221	test: 0.7402063	best: 0.7401896 (15695)	total: 4m 59s	remaining: 1m 14s
# 16200:	learn: 0.0484661	test: 0.7401788	best: 0.7401776 (16182)	total: 5m 3s	remaining: 1m 11s
# 16400:	learn: 0.0479391	test: 0.7401656	best: 0.7401656 (16400)	total: 5m 7s	remaining: 1m 7s
# 16600:	learn: 0.0474384	test: 0.7401294	best: 0.7401290 (16599)	total: 5m 11s	remaining: 1m 3s
# 16800:	learn: 0.0469403	test: 0.7401232	best: 0.7401227 (16799)	total: 5m 15s	remaining: 60s
# 17000:	learn: 0.0464436	test: 0.7401027	best: 0.7401027 (17000)	total: 5m 18s	remaining: 56.2s
# 17200:	learn: 0.0459759	test: 0.7401000	best: 0.7400918 (17071)	total: 5m 22s	remaining: 52.5s
# 17400:	learn: 0.0454992	test: 0.7400882	best: 0.7400863 (17302)	total: 5m 26s	remaining: 48.7s
# 17600:	learn: 0.0450377	test: 0.7400828	best: 0.7400817 (17565)	total: 5m 30s	remaining: 45s
# 17800:	learn: 0.0445815	test: 0.7400663	best: 0.7400645 (17754)	total: 5m 33s	remaining: 41.2s
# 18000:	learn: 0.0441526	test: 0.7400493	best: 0.7400486 (17991)	total: 5m 37s	remaining: 37.5s
# 18200:	learn: 0.0437191	test: 0.7400512	best: 0.7400485 (18006)	total: 5m 41s	remaining: 33.7s
# ...
# 14000:	learn: 0.0554454	test: 0.7379737	best: 0.7379695 (13942)	total: 4m 22s	remaining: 1m 52s
# 14200:	learn: 0.0547139	test: 0.7379586	best: 0.7379541 (14144)	total: 4m 26s	remaining: 1m 48s
# 14400:	learn: 0.0540727	test: 0.7379397	best: 0.7379397 (14400)	total: 4m 29s	remaining: 1m 44s
# 14600:	learn: 0.0533912	test: 0.7379116	best: 0.7379116 (14594)	total: 4m 33s	remaining: 1m 41s
# 14800:	learn: 0.0527534	test: 0.7378823	best: 0.7378810 (14797)	total: 4m 37s	remaining: 1m 37s
# 15000:	learn: 0.0521169	test: 0.7378626	best: 0.7378610 (14970)	total: 4m 41s	remaining: 1m 33s
# 15200:	learn: 0.0514932	test: 0.7378546	best: 0.7378546 (15200)	total: 4m 44s	remaining: 1m 29s
# 15400:	learn: 0.0509015	test: 0.7378341	best: 0.7378319 (15358)	total: 4m 48s	remaining: 1m 26s
# 15600:	learn: 0.0503019	test: 0.7378081	best: 0.7378048 (15589)	total: 4m 52s	remaining: 1m 22s
# 15800:	learn: 0.0497266	test: 0.7377815	best: 0.7377764 (15788)	total: 4m 56s	remaining: 1m 18s
# 16000:	learn: 0.0491786	test: 0.7377452	best: 0.7377452 (16000)	total: 4m 59s	remaining: 1m 14s
# 16200:	learn: 0.0486277	test: 0.7377413	best: 0.7377375 (16171)	total: 5m 3s	remaining: 1m 11s
# 16400:	learn: 0.0480942	test: 0.7377250	best: 0.7377229 (16395)	total: 5m 7s	remaining: 1m 7s
# 16600:	learn: 0.0475875	test: 0.7377089	best: 0.7377073 (16576)	total: 5m 11s	remaining: 1m 3s
# 16800:	learn: 0.0470845	test: 0.7376780	best: 0.7376780 (16800)	total: 5m 15s	remaining: 1m
# 17000:	learn: 0.0466207	test: 0.7376635	best: 0.7376575 (16909)	total: 5m 18s	remaining: 56.3s
# 17200:	learn: 0.0461357	test: 0.7376522	best: 0.7376495 (17186)	total: 5m 22s	remaining: 52.5s
# 17400:	learn: 0.0456861	test: 0.7376346	best: 0.7376346 (17400)	total: 5m 26s	remaining: 48.8s
# 17600:	learn: 0.0452316	test: 0.7376200	best: 0.7376191 (17599)	total: 5m 30s	remaining: 45s
# 17800:	learn: 0.0447907	test: 0.7376317	best: 0.7376191 (17599)	total: 5m 33s	remaining: 41.2s
# 18000:	learn: 0.0443853	test: 0.7376182	best: 0.7376175 (17993)	total: 5m 37s	remaining: 37.5s
# 18200:	learn: 0.0439082	test: 0.7376026	best: 0.7376003 (18141)	total: 5m 41s	remaining: 33.8s
# 18400:	learn: 0.0434922	test: 0.7375951	best: 0.7375937 (18397)	total: 5m 45s	remaining: 30s
# 18600:	learn: 0.0430644	test: 0.7375937	best: 0.7375871 (18431)	total: 5m 48s	remaining: 26.2s
# 18800:	learn: 0.0426795	test: 0.7375757	best: 0.7375748 (18789)	total: 5m 52s	remaining: 22.5s
# 19000:	learn: 0.0422854	test: 0.7375670	best: 0.7375656 (18986)	total: 5m 56s	remaining: 18.7s
# 19200:	learn: 0.0418944	test: 0.7375462	best: 0.7375453 (19192)	total: 6m	remaining: 15s
# 19400:	learn: 0.0415150	test: 0.7375344	best: 0.7375314 (19387)	total: 6m 4s	remaining: 11.2s
# 19600:	learn: 0.0411633	test: 0.7375302	best: 0.7375229 (19542)	total: 6m 7s	remaining: 7.49s
# 19800:	learn: 0.0407940	test: 0.7375304	best: 0.7375211 (19692)	total: 6m 11s	remaining: 3.73s
# 19999:	learn: 0.0404405	test: 0.7375235	best: 0.7375180 (19920)	total: 6m 15s	remaining: 0us
# bestTest = 0.7375180265
# bestIteration = 19920
# Shrink model to first 19921 iterations.
# Training Y coordinate model for fold 5...
# 0:	learn: 12.8500541	test: 12.6065544	best: 12.6065544 (0)	total: 33.7ms	remaining: 11m 13s
# 200:	learn: 0.6260027	test: 0.7447991	best: 0.7447991 (200)	total: 3.54s	remaining: 5m 49s
# 400:	learn: 0.4914433	test: 0.6962235	best: 0.6962235 (400)	total: 7.12s	remaining: 5m 48s
# 600:	learn: 0.4180801	test: 0.6793660	best: 0.6793660 (600)	total: 10.7s	remaining: 5m 45s
# 800:	learn: 0.3671275	test: 0.6694313	best: 0.6694313 (800)	total: 14.3s	remaining: 5m 43s
# 1000:	learn: 0.3288973	test: 0.6638624	best: 0.6638624 (1000)	total: 18s	remaining: 5m 41s
# 1200:	learn: 0.2991158	test: 0.6596773	best: 0.6596773 (1200)	total: 21.7s	remaining: 5m 39s
# 1400:	learn: 0.2754681	test: 0.6573082	best: 0.6573060 (1398)	total: 25.4s	remaining: 5m 36s
# 1600:	learn: 0.2549645	test: 0.6552790	best: 0.6552790 (1600)	total: 29.1s	remaining: 5m 34s
# 1800:	learn: 0.2380409	test: 0.6535538	best: 0.6535538 (1800)	total: 32.8s	remaining: 5m 31s
# 2000:	learn: 0.2231319	test: 0.6522748	best: 0.6522676 (1996)	total: 36.6s	remaining: 5m 28s
# 2200:	learn: 0.2104086	test: 0.6509901	best: 0.6509901 (2200)	total: 40.3s	remaining: 5m 25s
# 2400:	learn: 0.1991155	test: 0.6500489	best: 0.6500142 (2392)	total: 44.1s	remaining: 5m 22s
# 2600:	learn: 0.1887561	test: 0.6489916	best: 0.6489916 (2600)	total: 47.8s	remaining: 5m 20s
# 2800:	learn: 0.1794884	test: 0.6485277	best: 0.6485239 (2788)	total: 51.6s	remaining: 5m 16s
# 3000:	learn: 0.1709500	test: 0.6479645	best: 0.6479418 (2991)	total: 55.4s	remaining: 5m 14s
# 3200:	learn: 0.1636323	test: 0.6473955	best: 0.6473899 (3199)	total: 59.2s	remaining: 5m 10s
# 3400:	learn: 0.1566224	test: 0.6470064	best: 0.6469556 (3387)	total: 1m 3s	remaining: 5m 7s
# 3600:	learn: 0.1500582	test: 0.6466419	best: 0.6466419 (3600)	total: 1m 6s	remaining: 5m 4s
# 3800:	learn: 0.1444013	test: 0.6463729	best: 0.6463591 (3788)	total: 1m 10s	remaining: 5m
# 4000:	learn: 0.1389792	test: 0.6460591	best: 0.6460591 (4000)	total: 1m 14s	remaining: 4m 57s
# 4200:	learn: 0.1339966	test: 0.6457806	best: 0.6457806 (4200)	total: 1m 18s	remaining: 4m 54s
# 4400:	learn: 0.1294011	test: 0.6454971	best: 0.6454971 (4400)	total: 1m 21s	remaining: 4m 50s
# 4600:	learn: 0.1248207	test: 0.6452924	best: 0.6452874 (4599)	total: 1m 25s	remaining: 4m 47s
# 4800:	learn: 0.1207658	test: 0.6450205	best: 0.6450013 (4788)	total: 1m 29s	remaining: 4m 43s
# 5000:	learn: 0.1170137	test: 0.6448251	best: 0.6448251 (5000)	total: 1m 33s	remaining: 4m 40s
# 5200:	learn: 0.1133457	test: 0.6445509	best: 0.6445353 (5186)	total: 1m 37s	remaining: 4m 36s
# 5400:	learn: 0.1099914	test: 0.6445445	best: 0.6444923 (5361)	total: 1m 41s	remaining: 4m 33s
# 5600:	learn: 0.1067831	test: 0.6444343	best: 0.6444341 (5593)	total: 1m 44s	remaining: 4m 29s
# 5800:	learn: 0.1036110	test: 0.6443419	best: 0.6443244 (5764)	total: 1m 48s	remaining: 4m 25s
# 6000:	learn: 0.1008039	test: 0.6442080	best: 0.6442080 (6000)	total: 1m 52s	remaining: 4m 22s
# 6200:	learn: 0.0980725	test: 0.6441326	best: 0.6441209 (6168)	total: 1m 56s	remaining: 4m 18s
# 6400:	learn: 0.0955273	test: 0.6440412	best: 0.6440412 (6400)	total: 2m	remaining: 4m 15s
# 6600:	learn: 0.0930805	test: 0.6439330	best: 0.6439280 (6599)	total: 2m 3s	remaining: 4m 11s
# 6800:	learn: 0.0906940	test: 0.6438200	best: 0.6438124 (6795)	total: 2m 7s	remaining: 4m 7s
# 7000:	learn: 0.0885171	test: 0.6437239	best: 0.6437239 (7000)	total: 2m 11s	remaining: 4m 4s
# 7200:	learn: 0.0864353	test: 0.6436436	best: 0.6436436 (7200)	total: 2m 15s	remaining: 4m
# 7400:	learn: 0.0844819	test: 0.6435893	best: 0.6435893 (7400)	total: 2m 19s	remaining: 3m 56s
# 7600:	learn: 0.0825790	test: 0.6435893	best: 0.6435838 (7595)	total: 2m 22s	remaining: 3m 52s
# 7800:	learn: 0.0807762	test: 0.6435020	best: 0.6435020 (7800)	total: 2m 26s	remaining: 3m 49s
# 8000:	learn: 0.0789768	test: 0.6434392	best: 0.6434361 (7988)	total: 2m 30s	remaining: 3m 45s
# 8200:	learn: 0.0773019	test: 0.6433743	best: 0.6433616 (8189)	total: 2m 34s	remaining: 3m 42s
# 8400:	learn: 0.0756690	test: 0.6433187	best: 0.6433151 (8388)	total: 2m 38s	remaining: 3m 38s
# 8600:	learn: 0.0742103	test: 0.6432559	best: 0.6432543 (8599)	total: 2m 41s	remaining: 3m 34s
# 8800:	learn: 0.0727319	test: 0.6431834	best: 0.6431820 (8786)	total: 2m 45s	remaining: 3m 30s
# 9000:	learn: 0.0712616	test: 0.6431653	best: 0.6431592 (8988)	total: 2m 49s	remaining: 3m 27s
# 9200:	learn: 0.0698628	test: 0.6431143	best: 0.6431117 (9198)	total: 2m 53s	remaining: 3m 23s
# 9400:	learn: 0.0685440	test: 0.6430926	best: 0.6430882 (9393)	total: 2m 57s	remaining: 3m 19s
# 9600:	learn: 0.0672665	test: 0.6430414	best: 0.6430369 (9498)	total: 3m 1s	remaining: 3m 16s
# 9800:	learn: 0.0660219	test: 0.6430044	best: 0.6430039 (9797)	total: 3m 4s	remaining: 3m 12s
# 10000:	learn: 0.0648785	test: 0.6429545	best: 0.6429486 (9987)	total: 3m 8s	remaining: 3m 8s
# 10200:	learn: 0.0637302	test: 0.6429083	best: 0.6429014 (10187)	total: 3m 12s	remaining: 3m 4s
# 10400:	learn: 0.0626442	test: 0.6428385	best: 0.6428385 (10400)	total: 3m 16s	remaining: 3m 1s
# 10600:	learn: 0.0615931	test: 0.6428213	best: 0.6428213 (10600)	total: 3m 20s	remaining: 2m 57s
# 10800:	learn: 0.0606167	test: 0.6427805	best: 0.6427782 (10791)	total: 3m 23s	remaining: 2m 53s
# 11000:	learn: 0.0596359	test: 0.6427395	best: 0.6427385 (10993)	total: 3m 27s	remaining: 2m 49s
# 11200:	learn: 0.0587132	test: 0.6427150	best: 0.6427101 (11136)	total: 3m 31s	remaining: 2m 46s
# 11400:	learn: 0.0578121	test: 0.6426872	best: 0.6426872 (11400)	total: 3m 35s	remaining: 2m 42s
# 11600:	learn: 0.0569328	test: 0.6426581	best: 0.6426564 (11582)	total: 3m 39s	remaining: 2m 38s
# 11800:	learn: 0.0560976	test: 0.6426353	best: 0.6426346 (11798)	total: 3m 42s	remaining: 2m 34s
# 12000:	learn: 0.0553092	test: 0.6426171	best: 0.6426141 (11992)	total: 3m 46s	remaining: 2m 31s
# 12200:	learn: 0.0544993	test: 0.6425606	best: 0.6425591 (12199)	total: 3m 50s	remaining: 2m 27s
# 12400:	learn: 0.0537012	test: 0.6425368	best: 0.6425337 (12394)	total: 3m 54s	remaining: 2m 23s
# 12600:	learn: 0.0529568	test: 0.6425127	best: 0.6425095 (12596)	total: 3m 58s	remaining: 2m 19s
# 12800:	learn: 0.0521947	test: 0.6425117	best: 0.6424884 (12731)	total: 4m 1s	remaining: 2m 16s
# 13000:	learn: 0.0515016	test: 0.6424734	best: 0.6424734 (13000)	total: 4m 5s	remaining: 2m 12s
# 13200:	learn: 0.0508204	test: 0.6424469	best: 0.6424440 (13197)	total: 4m 9s	remaining: 2m 8s
# 13400:	learn: 0.0501630	test: 0.6424278	best: 0.6424229 (13347)	total: 4m 13s	remaining: 2m 4s
# 13600:	learn: 0.0495358	test: 0.6424309	best: 0.6424229 (13347)	total: 4m 17s	remaining: 2m
# 13800:	learn: 0.0489188	test: 0.6424135	best: 0.6424084 (13791)	total: 4m 20s	remaining: 1m 57s
# 14000:	learn: 0.0483058	test: 0.6424111	best: 0.6423989 (13854)	total: 4m 24s	remaining: 1m 53s
# 14200:	learn: 0.0477393	test: 0.6423989	best: 0.6423971 (14154)	total: 4m 28s	remaining: 1m 49s
# 14400:	learn: 0.0471619	test: 0.6423802	best: 0.6423764 (14373)	total: 4m 32s	remaining: 1m 45s
# 14600:	learn: 0.0466187	test: 0.6423693	best: 0.6423656 (14548)	total: 4m 36s	remaining: 1m 42s
# 14800:	learn: 0.0460741	test: 0.6423386	best: 0.6423345 (14793)	total: 4m 39s	remaining: 1m 38s
# 15000:	learn: 0.0455655	test: 0.6423295	best: 0.6423261 (14977)	total: 4m 43s	remaining: 1m 34s
# 15200:	learn: 0.0450520	test: 0.6423074	best: 0.6423045 (15188)	total: 4m 47s	remaining: 1m 30s
# 15400:	learn: 0.0445623	test: 0.6423045	best: 0.6422991 (15327)	total: 4m 51s	remaining: 1m 26s
# 15600:	learn: 0.0440826	test: 0.6423048	best: 0.6422991 (15327)	total: 4m 55s	remaining: 1m 23s
# 15800:	learn: 0.0436033	test: 0.6422994	best: 0.6422948 (15781)	total: 4m 58s	remaining: 1m 19s
# 16000:	learn: 0.0431562	test: 0.6422916	best: 0.6422897 (15866)	total: 5m 2s	remaining: 1m 15s
# 16200:	learn: 0.0427057	test: 0.6422633	best: 0.6422633 (16200)	total: 5m 6s	remaining: 1m 11s
# 16400:	learn: 0.0422634	test: 0.6422621	best: 0.6422603 (16319)	total: 5m 10s	remaining: 1m 8s
# 16600:	learn: 0.0418055	test: 0.6422519	best: 0.6422509 (16596)	total: 5m 14s	remaining: 1m 4s
# 16800:	learn: 0.0413861	test: 0.6422401	best: 0.6422401 (16800)	total: 5m 17s	remaining: 1m
# 17000:	learn: 0.0409793	test: 0.6422366	best: 0.6422303 (16896)	total: 5m 21s	remaining: 56.7s
# 17200:	learn: 0.0405941	test: 0.6422172	best: 0.6422156 (17179)	total: 5m 25s	remaining: 53s
# 17400:	learn: 0.0402111	test: 0.6422001	best: 0.6421953 (17360)	total: 5m 29s	remaining: 49.2s
# 17600:	learn: 0.0398133	test: 0.6421966	best: 0.6421920 (17574)	total: 5m 33s	remaining: 45.4s
# 17800:	learn: 0.0394369	test: 0.6421799	best: 0.6421799 (17800)	total: 5m 36s	remaining: 41.6s
# 18000:	learn: 0.0390797	test: 0.6421806	best: 0.6421776 (17831)	total: 5m 40s	remaining: 37.8s
# 18200:	learn: 0.0387230	test: 0.6421686	best: 0.6421680 (18196)	total: 5m 44s	remaining: 34s
# 18400:	learn: 0.0383866	test: 0.6421685	best: 0.6421645 (18233)	total: 5m 48s	remaining: 30.2s
# 18600:	learn: 0.0380380	test: 0.6421669	best: 0.6421627 (18534)	total: 5m 51s	remaining: 26.5s
# 18800:	learn: 0.0377027	test: 0.6421534	best: 0.6421534 (18800)	total: 5m 55s	remaining: 22.7s
# 19000:	learn: 0.0373615	test: 0.6421466	best: 0.6421425 (18889)	total: 5m 59s	remaining: 18.9s
# 19200:	learn: 0.0370380	test: 0.6421393	best: 0.6421345 (19175)	total: 6m 3s	remaining: 15.1s
# 19400:	learn: 0.0367112	test: 0.6421274	best: 0.6421261 (19333)	total: 6m 6s	remaining: 11.3s
# 19600:	learn: 0.0363891	test: 0.6421138	best: 0.6421138 (19595)	total: 6m 10s	remaining: 7.55s
# 19800:	learn: 0.0360811	test: 0.6421060	best: 0.6421059 (19799)	total: 6m 14s	remaining: 3.76s
# 19999:	learn: 0.0357685	test: 0.6420986	best: 0.6420949 (19902)	total: 6m 18s	remaining: 0us
# bestTest = 0.6420949089
# bestIteration = 19902
# Shrink model to first 19903 iterations.
# Fold 5 RMSE: 0.6914
#
# Average CatBoost RMSE across 5 folds: 0.7150
# Standard Deviation of RMSE: 0.0426
#
# ============================================================
# ULTRA-OPTIMIZED CATBOOST PERFORMANCE (5-FOLD GROUPKFOLD CV)
# ============================================================
# Physics Baseline RMSE:     5.6845
# Ultra-Optimized CatBoost:  0.7150
# Improvement:               87.42%
# Target RMSE:               0.9000
# Target Met:                YES - TARGET ACHIEVED!
# ============================================================
#
# Top 30 Most Important Features (Averaged across folds):
#                       feature  importance_x  importance_y  importance_avg
# 0                           x     45.203774      0.011157       22.607465
# 1                           y      0.011199     35.211784       17.611491
# 23                   frame_id      7.162663     13.024098       10.093381
# 6                  velocity_x      0.008115      8.786010        4.397063
# 20                ball_land_x      7.551625      0.028063        3.789844
# 83           x_rolling_mean_5      7.380292      0.003834        3.692063
# 75           y_rolling_mean_3      0.004272      6.620713        3.312492
# 73           x_rolling_mean_3      6.479843      0.003829        3.241836
# 44                     y_lag1      0.004023      5.466110        2.735066
# 43                     x_lag1      4.562529      0.004397        2.283463
# 93           velocity_x_delta      0.037347      4.213861        2.125604
# 21                ball_land_y      0.048629      3.770938        1.909784
# 49                     x_lag2      3.635614      0.004382        1.819998
# 76            y_rolling_std_3      0.015364      3.585228        1.800296
# 7                  velocity_y      2.950257      0.015235        1.482746
# 85           y_rolling_mean_5      0.004750      2.924903        1.464827
# 24             acceleration_x      0.013038      2.803041        1.408040
# 36                 momentum_x      0.008178      2.286351        1.147264
# 77  velocity_x_rolling_mean_3      0.003462      2.259280        1.131371
# 79  velocity_y_rolling_mean_3      2.089973      0.005464        1.047719
# 74            x_rolling_std_3      1.640825      0.060700        0.850763
# 50                     y_lag2      0.003293      1.615622        0.809457
# 5                         dir      1.532259      0.028214        0.780236
# 94           velocity_y_delta      1.170840      0.071371        0.621106
# 86            y_rolling_std_5      0.011308      1.116741        0.564024
# 27       distance_to_target_y      0.051568      1.016890        0.534229
# 55                     x_lag3      1.041460      0.006193        0.523826
# 37                 momentum_y      0.974548      0.016369        0.495458
# 46            velocity_y_lag1      0.970896      0.003997        0.487446
# 56                     y_lag3      0.004981      0.937722        0.471352
#
# Models saved to catboost_5fold_models.pkl
#
# === Generating Submission ===
# Engineering features for test data...
#
# [SUCCESS] Submission saved: submission_catboost_5fold.csv
# Shape: (5837, 3)
#
# === Submission Validation ===
# No NaN values: True
# X range: [2.07, 117.40]
# Y range: [1.25, 52.61]
# Unique IDs: 5837
#
# [FINAL] Validation RMSE: 0.7150
# [FINAL] Target RMSE < 0.9: ACHIEVED!
